# %%
import import_ipynb
import os
import pandas as pd
import gensim
from collections import Counter
from pprint import pprint

from WNDomains import WordNetDomains 
wnd = WordNetDomains(wordnet_home='.')
# Out:
# importing Jupyter notebook from WNDomains.ipynb

# %%
import nltk
from nltk.corpus import stopwords
en_stopwords = stopwords.words('english') + ['return']

# %%
import spacy
nlp = spacy.load('en')

path= r'/Users/valeriaguttilla/Desktop/MASTER/PROGETTONE/ANALISI_TESTUALE/ANALISI TRAME/TRAME/ANIMATED/'

#domains_trama = set()  


list1=[1990, 2000, 2010]
dict_all_domains={}

for dirpath, dirnames, files in os.walk(path):
    dict_domains = {}
    
    for file in files:
        if file[0] == '.':
            continue

        domains_trama_all = set()
        counter = Counter()

        with open(dirpath+ "/" + file, 'r', encoding='Latin-1') as f:
            text = f.read()
            doc = nlp(text)
            #words = set([token.text if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in ['NOUN']])
            words = set([token.text for token in doc if (len(token.text) > 2 and token.pos_ in ['NOUN', 'PROPN'])])
            #words = set(gensim.utils.simple_preprocess(text, deacc=True))
            words = words.difference(en_stopwords) 

            file=file.split('.')[0]
            decade=dirpath.split('/')[-1]

            for word in words:
                domain = wnd.get_domains(word, 'n', first_sense_only=True)
                if 'factotum' in domain:
                    continue
                    
                for tmp_d in domain:
                    counter[tmp_d] += 1
                if len(domain) > 0:
                    print(file, word, '->', domain)
                    if  counter[tmp_d] > 1:
                        domains_trama_all |= domain
                
                
            print(file)
            pprint(counter)

            for domain in domains_trama_all:
                if domain in dict_domains:
                    dict_domains[domain].append(file)
                else:
                    dict_domains[domain] = [file]
   # print(dict_domains)
    for d in dict_domains:
        if decade in list1:
            if len(dict_domains[d]) >= (len(files)/2):
                if d in dict_all_domains:
                    dict_all_domains[d].append(decade)
                else:
                    dict_all_domains[d] = [decade]
        else:
            if len(dict_domains[d]) >= (len(files)*(0.5)):
                if d in dict_all_domains:
                    dict_all_domains[d].append(decade)
                else:
                    dict_all_domains[d] = [decade]
# Out:
# sottotitoli_domains_prove_varie worksheets -> {'publishing'}
# sottotitoli_domains_prove_varie
# Counter({'publishing': 1})
# The Little Mermaid garden -> {'town_planning', 'agriculture'}
# The Little Mermaid friend -> {'person'}
# The Little Mermaid storm -> {'meteorology'}
# The Little Mermaid sun -> {'astronomy'}
# The Little Mermaid polyps -> {'medicine'}
# The Little Mermaid King -> {'history', 'person'}
# The Little Mermaid animals -> {'biology', 'animals'}
# The Little Mermaid consciousness -> {'psychology'}
# The Little Mermaid Prince -> {'heraldry'}
# The Little Mermaid grotto -> {'earth'}
# The Little Mermaid seagull -> {'animals'}
# The Little Mermaid release -> {'commerce'}
# The Little Mermaid marriage -> {'law', 'sociology'}
# The Little Mermaid castle -> {'buildings'}
# The Little Mermaid neck -> {'anatomy'}
# The Little Mermaid Ocean -> {'geography'}
# The Little Mermaid trident -> {'military'}
# The Little Mermaid ocean -> {'geography'}
# The Little Mermaid beach -> {'geology'}
# The Little Mermaid exchange -> {'chemistry'}
# The Little Mermaid enchantment -> {'psychological_features'}
# The Little Mermaid Vanessa -> {'biology', 'animals'}
# The Little Mermaid deal -> {'commerce'}
# The Little Mermaid culture -> {'anthropology'}
# The Little Mermaid composer -> {'music'}
# The Little Mermaid birthday -> {'time_period'}
# The Little Mermaid barge -> {'nautical'}
# The Little Mermaid ships -> {'economy', 'nautical'}
# The Little Mermaid days -> {'time_period'}
# The Little Mermaid celebration -> {'sociology'}
# The Little Mermaid wedding -> {'sociology', 'religion'}
# The Little Mermaid adviser -> {'person'}
# The Little Mermaid legs -> {'quality'}
# The Little Mermaid harpoon -> {'fishing'}
# The Little Mermaid behavior -> {'psychology'}
# The Little Mermaid father -> {'person'}
# The Little Mermaid ruler -> {'metrology'}
# The Little Mermaid forms -> {'linguistics'}
# The Little Mermaid bowsprit -> {'nautical'}
# The Little Mermaid Triton -> {'mythology'}
# The Little Mermaid servant -> {'person'}
# The Little Mermaid shell -> {'military'}
# The Little Mermaid voice -> {'acoustics'}
# The Little Mermaid travel -> {'tourism'}
# The Little Mermaid princess -> {'heraldry'}
# The Little Mermaid sea -> {'geography'}
# The Little Mermaid human -> {'person', 'biology'}
# The Little Mermaid crab -> {'biology', 'entomology'}
# The Little Mermaid Flounder -> {'food', 'chemistry'}
# The Little Mermaid Atlantic -> {'geography'}
# The Little Mermaid witch -> {'occultism'}
# The Little Mermaid court -> {'law', 'town_planning'}
# The Little Mermaid daughter -> {'person'}
# The Little Mermaid polyp -> {'medicine'}
# The Little Mermaid eels -> {'food', 'animals', 'chemistry'}
# The Little Mermaid love -> {'psychological_features'}
# The Little Mermaid ship -> {'economy', 'nautical'}
# The Little Mermaid night -> {'time_period'}
# The Little Mermaid song -> {'music'}
# The Little Mermaid
# Counter({'person': 7,
#          'biology': 4,
#          'animals': 4,
#          'geography': 4,
#          'nautical': 4,
#          'sociology': 3,
#          'chemistry': 3,
#          'time_period': 3,
#          'town_planning': 2,
#          'medicine': 2,
#          'psychology': 2,
#          'heraldry': 2,
#          'commerce': 2,
#          'law': 2,
#          'military': 2,
#          'psychological_features': 2,
#          'music': 2,
#          'economy': 2,
#          'food': 2,
#          'agriculture': 1,
#          'meteorology': 1,
#          'astronomy': 1,
#          'history': 1,
#          'earth': 1,
#          'buildings': 1,
#          'anatomy': 1,
#          'geology': 1,
#          'anthropology': 1,
#          'religion': 1,
#          'quality': 1,
#          'fishing': 1,
#          'metrology': 1,
#          'linguistics': 1,
#          'mythology': 1,
#          'acoustics': 1,
#          'tourism': 1,
#          'entomology': 1,
#          'occultism': 1})
# The Fox and the Hound friend -> {'person'}
# The Fox and the Hound argument -> {'telecommunication'}
# The Fox and the Hound lake -> {'geography'}
# The Fox and the Hound adulthood -> {'time_period'}
# The Fox and the Hound friends -> {'person'}
# The Fox and the Hound neighbor -> {'person'}
# The Fox and the Hound Amos -> {'religion'}
# The Fox and the Hound farm -> {'agriculture'}
# The Fox and the Hound badger -> {'animals'}
# The Fox and the Hound Dinky -> {'railway'}
# The Fox and the Hound hill -> {'tourism', 'geography', 'geology'}
# The Fox and the Hound porcupine -> {'animals'}
# The Fox and the Hound forest -> {'plants', 'biology'}
# The Fox and the Hound entrance -> {'transport'}
# The Fox and the Hound dogs -> {'biology', 'animals'}
# The Fox and the Hound trespass -> {'sociology'}
# The Fox and the Hound enemies -> {'military'}
# The Fox and the Hound hunter -> {'hunting'}
# The Fox and the Hound playmates -> {'person'}
# The Fox and the Hound Tod -> {'metrology'}
# The Fox and the Hound woods -> {'plants', 'biology'}
# The Fox and the Hound Mama -> {'person'}
# The Fox and the Hound Boomer -> {'biology'}
# The Fox and the Hound morning -> {'time_period'}
# The Fox and the Hound trips -> {'tourism'}
# The Fox and the Hound gun -> {'military'}
# The Fox and the Hound wilderness -> {'geography'}
# The Fox and the Hound health -> {'medicine'}
# The Fox and the Hound reach -> {'mathematics'}
# The Fox and the Hound leg -> {'anatomy'}
# The Fox and the Hound burrow -> {'geology'}
# The Fox and the Hound finch -> {'biology', 'animals'}
# The Fox and the Hound Chief -> {'person'}
# The Fox and the Hound months -> {'time_period'}
# The Fox and the Hound woodpecker -> {'biology', 'animals'}
# The Fox and the Hound days -> {'time_period'}
# The Fox and the Hound owl -> {'biology', 'animals'}
# The Fox and the Hound river -> {'geography', 'tourism'}
# The Fox and the Hound Copper -> {'electricity', 'chemistry'}
# The Fox and the Hound blame -> {'law'}
# The Fox and the Hound bank -> {'banking'}
# The Fox and the Hound fox -> {'animals'}
# The Fox and the Hound bear -> {'biology', 'animals'}
# The Fox and the Hound kill -> {'sociology'}
# The Fox and the Hound dog -> {'biology', 'animals'}
# The Fox and the Hound fishing -> {'fishing'}
# The Fox and the Hound den -> {'geography'}
# The Fox and the Hound game -> {'sport'}
# The Fox and the Hound waterfall -> {'geography', 'tourism'}
# The Fox and the Hound foxes -> {'animals'}
# The Fox and the Hound grizzly -> {'animals'}
# The Fox and the Hound toddler -> {'person'}
# The Fox and the Hound puppy -> {'animals'}
# The Fox and the Hound Tweed -> {'industry'}
# The Fox and the Hound hunting -> {'hunting'}
# The Fox and the Hound train -> {'transport'}
# The Fox and the Hound railroad -> {'transport'}
# The Fox and the Hound season -> {'time_period'}
# The Fox and the Hound doghouse -> {'buildings', 'town_planning'}
# The Fox and the Hound Momma -> {'person'}
# The Fox and the Hound night -> {'time_period'}
# The Fox and the Hound interim -> {'time_period'}
# The Fox and the Hound
# Counter({'animals': 12,
#          'biology': 9,
#          'person': 8,
#          'time_period': 7,
#          'geography': 6,
#          'tourism': 4,
#          'transport': 3,
#          'geology': 2,
#          'plants': 2,
#          'sociology': 2,
#          'military': 2,
#          'hunting': 2,
#          'telecommunication': 1,
#          'religion': 1,
#          'agriculture': 1,
#          'railway': 1,
#          'metrology': 1,
#          'medicine': 1,
#          'mathematics': 1,
#          'anatomy': 1,
#          'electricity': 1,
#          'chemistry': 1,
#          'law': 1,
#          'banking': 1,
#          'fishing': 1,
#          'sport': 1,
#          'industry': 1,
#          'buildings': 1,
#          'town_planning': 1})
# Oliver & Company strays -> {'animals'}
# Oliver & Company Jenny -> {'architecture'}
# Oliver & Company subway -> {'transport'}
# Oliver & Company butler -> {'person'}
# Oliver & Company Einstein -> {'physics'}
# Oliver & Company bounty -> {'economy'}
# Oliver & Company call -> {'telephony'}
# Oliver & Company debt -> {'finance'}
# Oliver & Company phone -> {'furniture', 'telephony'}
# Oliver & Company Fifth -> {'metrology'}
# Oliver & Company Fagin -> {'literature'}
# Oliver & Company animals -> {'biology', 'animals'}
# Oliver & Company limousine -> {'transport'}
# Oliver & Company kittens -> {'animals'}
# Oliver & Company theft -> {'law'}
# Oliver & Company shark -> {'animals'}
# Oliver & Company money -> {'money'}
# Oliver & Company dogs -> {'biology', 'animals'}
# Oliver & Company Oliver -> {'music'}
# Oliver & Company Dane -> {'geography'}
# Oliver & Company morning -> {'time_period'}
# Oliver & Company Tito -> {'history', 'politics'}
# Oliver & Company chihuahua -> {'administration', 'geography'}
# Oliver & Company food -> {'food'}
# Oliver & Company conscience -> {'religion'}
# Oliver & Company note -> {'post'}
# Oliver & Company tunnels -> {'buildings', 'town_planning'}
# Oliver & Company parents -> {'person'}
# Oliver & Company meal -> {'gastronomy'}
# Oliver & Company pickpocket -> {'law'}
# Oliver & Company Dodger -> {'law'}
# Oliver & Company Saluki -> {'animals', 'hunting'}
# Oliver & Company kitten -> {'animals'}
# Oliver & Company disgust -> {'psychological_features'}
# Oliver & Company family -> {'person'}
# Oliver & Company deal -> {'commerce'}
# Oliver & Company owner -> {'economy', 'commerce'}
# Oliver & Company barge -> {'nautical'}
# Oliver & Company birthday -> {'time_period'}
# Oliver & Company scooter -> {'nautical'}
# Oliver & Company Rome -> {'geography'}
# Oliver & Company days -> {'time_period'}
# Oliver & Company household -> {'person'}
# Oliver & Company house -> {'buildings', 'town_planning'}
# Oliver & Company rail -> {'buildings'}
# Oliver & Company ransom -> {'economy'}
# Oliver & Company vendor -> {'commerce'}
# Oliver & Company collar -> {'fashion'}
# Oliver & Company gang -> {'law'}
# Oliver & Company dog -> {'biology', 'animals'}
# Oliver & Company bulldog -> {'animals'}
# Oliver & Company goods -> {'commerce'}
# Oliver & Company poodle -> {'animals'}
# Oliver & Company car -> {'transport', 'tourism'}
# Oliver & Company train -> {'transport'}
# Oliver & Company Georgette -> {'industry'}
# Oliver & Company Dobermans -> {'animals'}
# Oliver & Company daughter -> {'person'}
# Oliver & Company streets -> {'transport', 'town_planning'}
# Oliver & Company
# Counter({'animals': 11,
#          'transport': 5,
#          'person': 5,
#          'law': 4,
#          'commerce': 4,
#          'economy': 3,
#          'biology': 3,
#          'geography': 3,
#          'time_period': 3,
#          'buildings': 3,
#          'town_planning': 3,
#          'telephony': 2,
#          'nautical': 2,
#          'architecture': 1,
#          'physics': 1,
#          'finance': 1,
#          'furniture': 1,
#          'metrology': 1,
#          'literature': 1,
#          'money': 1,
#          'music': 1,
#          'history': 1,
#          'politics': 1,
#          'administration': 1,
#          'food': 1,
#          'religion': 1,
#          'post': 1,
#          'gastronomy': 1,
#          'hunting': 1,
#          'psychological_features': 1,
#          'fashion': 1,
#          'tourism': 1,
#          'industry': 1})
# The Great Mouse Detective shop -> {'buildings', 'town_planning'}
# The Great Mouse Detective uniforms -> {'fashion'}
# The Great Mouse Detective machine -> {'buildings'}
# The Great Mouse Detective Dr. -> {'school'}
# The Great Mouse Detective treason -> {'law'}
# The Great Mouse Detective cat -> {'animals'}
# The Great Mouse Detective toy -> {'play'}
# The Great Mouse Detective henchmen -> {'law'}
# The Great Mouse Detective Mice -> {'animals'}
# The Great Mouse Detective Professor -> {'university', 'school'}
# The Great Mouse Detective tosses -> {'betting'}
# The Great Mouse Detective Hound -> {'biology', 'animals', 'hunting'}
# The Great Mouse Detective Holmes -> {'literature'}
# The Great Mouse Detective client -> {'law'}
# The Great Mouse Detective spring -> {'time_period'}
# The Great Mouse Detective dirigible -> {'transport'}
# The Great Mouse Detective Fidget -> {'psychological_features'}
# The Great Mouse Detective fraud -> {'law', 'economy'}
# The Great Mouse Detective pet -> {'animals'}
# The Great Mouse Detective cape -> {'geography'}
# The Great Mouse Detective Rube -> {'person'}
# The Great Mouse Detective Basset -> {'animals', 'hunting'}
# The Great Mouse Detective sailors -> {'nautical'}
# The Great Mouse Detective Basil -> {'plants', 'biology'}
# The Great Mouse Detective bell -> {'acoustics'}
# The Great Mouse Detective Mouse -> {'animals'}
# The Great Mouse Detective mechanisms -> {'chemistry'}
# The Great Mouse Detective Sherlock -> {'law'}
# The Great Mouse Detective robot -> {'mechanics', 'industry'}
# The Great Mouse Detective tests -> {'psychology', 'metrology'}
# The Great Mouse Detective rat -> {'animals'}
# The Great Mouse Detective sound -> {'acoustics'}
# The Great Mouse Detective Goldberg -> {'art'}
# The Great Mouse Detective June -> {'time_period', 'metrology'}
# The Great Mouse Detective David -> {'person', 'religion'}
# The Great Mouse Detective soldiers -> {'military'}
# The Great Mouse Detective Regiment -> {'military'}
# The Great Mouse Detective Toby -> {'furniture'}
# The Great Mouse Detective tyrant -> {'history'}
# The Great Mouse Detective henchman -> {'law'}
# The Great Mouse Detective villain -> {'person'}
# The Great Mouse Detective leg -> {'anatomy'}
# The Great Mouse Detective Dawson -> {'geography'}
# The Great Mouse Detective forces -> {'military'}
# The Great Mouse Detective head -> {'animals', 'anatomy'}
# The Great Mouse Detective bat -> {'biology', 'animals'}
# The Great Mouse Detective Queen -> {'entomology'}
# The Great Mouse Detective surgeon -> {'medicine'}
# The Great Mouse Detective birthday -> {'time_period'}
# The Great Mouse Detective mouse -> {'animals'}
# The Great Mouse Detective Afghanistan -> {'geography'}
# The Great Mouse Detective associate -> {'person', 'economy'}
# The Great Mouse Detective tavern -> {'buildings'}
# The Great Mouse Detective sewer -> {'hydraulics', 'town_planning'}
# The Great Mouse Detective hostage -> {'law'}
# The Great Mouse Detective house -> {'buildings', 'town_planning'}
# The Great Mouse Detective father -> {'person'}
# The Great Mouse Detective London -> {'geography'}
# The Great Mouse Detective ruler -> {'metrology'}
# The Great Mouse Detective clock -> {'metrology'}
# The Great Mouse Detective Street -> {'transport', 'town_planning'}
# The Great Mouse Detective balloons -> {'play'}
# The Great Mouse Detective Thames -> {'geography'}
# The Great Mouse Detective Detective -> {'administration', 'military'}
# The Great Mouse Detective Baker -> {'commerce'}
# The Great Mouse Detective one -> {'number'}
# The Great Mouse Detective wing -> {'anatomy', 'entomology'}
# The Great Mouse Detective years -> {'time_period'}
# The Great Mouse Detective Rat -> {'animals'}
# The Great Mouse Detective adventures -> {'tourism'}
# The Great Mouse Detective queen -> {'entomology'}
# The Great Mouse Detective gears -> {'mechanics'}
# The Great Mouse Detective clockwork -> {'mechanics'}
# The Great Mouse Detective window -> {'buildings'}
# The Great Mouse Detective Felicia -> {'plants', 'biology'}
# The Great Mouse Detective Ben -> {'geography', 'geology'}
# The Great Mouse Detective Union -> {'economy', 'politics'}
# The Great Mouse Detective Palace -> {'buildings'}
# The Great Mouse Detective helium -> {'physics', 'chemistry'}
# The Great Mouse Detective
# Counter({'animals': 11,
#          'law': 7,
#          'buildings': 6,
#          'geography': 6,
#          'person': 5,
#          'town_planning': 4,
#          'biology': 4,
#          'time_period': 4,
#          'metrology': 4,
#          'military': 4,
#          'economy': 3,
#          'mechanics': 3,
#          'anatomy': 3,
#          'entomology': 3,
#          'school': 2,
#          'play': 2,
#          'hunting': 2,
#          'transport': 2,
#          'plants': 2,
#          'acoustics': 2,
#          'chemistry': 2,
#          'fashion': 1,
#          'university': 1,
#          'betting': 1,
#          'literature': 1,
#          'psychological_features': 1,
#          'nautical': 1,
#          'industry': 1,
#          'psychology': 1,
#          'art': 1,
#          'religion': 1,
#          'furniture': 1,
#          'history': 1,
#          'medicine': 1,
#          'hydraulics': 1,
#          'administration': 1,
#          'commerce': 1,
#          'number': 1,
#          'tourism': 1,
#          'geology': 1,
#          'politics': 1,
#          'physics': 1})
# The Black Cauldron Wen -> {'medicine'}
# The Black Cauldron magic -> {'religion'}
# The Black Cauldron friend -> {'person'}
# The Black Cauldron goblin -> {'folklore'}
# The Black Cauldron dragon -> {'mythology'}
# The Black Cauldron sword -> {'military'}
# The Black Cauldron escort -> {'person', 'military'}
# The Black Cauldron leader -> {'person'}
# The Black Cauldron King -> {'history', 'person'}
# The Black Cauldron friends -> {'person'}
# The Black Cauldron tunnel -> {'buildings', 'town_planning'}
# The Black Cauldron creature -> {'biology', 'animals'}
# The Black Cauldron assistant -> {'person'}
# The Black Cauldron farm -> {'agriculture'}
# The Black Cauldron arms -> {'military'}
# The Black Cauldron Cauldron -> {'gastronomy'}
# The Black Cauldron pig -> {'biology', 'animals'}
# The Black Cauldron companions -> {'person'}
# The Black Cauldron captive -> {'law'}
# The Black Cauldron minions -> {'economy'}
# The Black Cauldron catacombs -> {'buildings', 'town_planning'}
# The Black Cauldron castle -> {'buildings'}
# The Black Cauldron antics -> {'free_time'}
# The Black Cauldron dream -> {'physiology'}
# The Black Cauldron Enchanter -> {'occultism'}
# The Black Cauldron soldiers -> {'military'}
# The Black Cauldron bard -> {'literature'}
# The Black Cauldron turn -> {'transport'}
# The Black Cauldron warrior -> {'military'}
# The Black Cauldron youth -> {'person'}
# The Black Cauldron Princess -> {'heraldry'}
# The Black Cauldron land -> {'economy'}
# The Black Cauldron exchange -> {'chemistry'}
# The Black Cauldron relic -> {'archaeology'}
# The Black Cauldron Fair -> {'free_time'}
# The Black Cauldron witches -> {'occultism'}
# The Black Cauldron warriors -> {'military'}
# The Black Cauldron king -> {'history', 'person'}
# The Black Cauldron fear -> {'psychological_features'}
# The Black Cauldron Marshes -> {'geography'}
# The Black Cauldron belief -> {'religion'}
# The Black Cauldron hand -> {'person', 'anatomy'}
# The Black Cauldron Hen -> {'animals'}
# The Black Cauldron dog -> {'biology', 'animals'}
# The Black Cauldron dungeon -> {'military'}
# The Black Cauldron marshes -> {'geography'}
# The Black Cauldron keeper -> {'person'}
# The Black Cauldron cauldron -> {'gastronomy'}
# The Black Cauldron heroism -> {'psychological_features'}
# The Black Cauldron prisoner -> {'law'}
# The Black Cauldron love -> {'psychological_features'}
# The Black Cauldron Creeper -> {'plants'}
# The Black Cauldron creatures -> {'biology', 'animals'}
# The Black Cauldron Black -> {'color'}
# The Black Cauldron army -> {'military'}
# The Black Cauldron
# Counter({'person': 11,
#          'military': 8,
#          'animals': 5,
#          'biology': 4,
#          'buildings': 3,
#          'psychological_features': 3,
#          'religion': 2,
#          'history': 2,
#          'town_planning': 2,
#          'gastronomy': 2,
#          'law': 2,
#          'economy': 2,
#          'free_time': 2,
#          'occultism': 2,
#          'geography': 2,
#          'medicine': 1,
#          'folklore': 1,
#          'mythology': 1,
#          'agriculture': 1,
#          'physiology': 1,
#          'literature': 1,
#          'transport': 1,
#          'heraldry': 1,
#          'chemistry': 1,
#          'archaeology': 1,
#          'anatomy': 1,
#          'plants': 1,
#          'color': 1})
# The Jungle Book mate -> {'person', 'nautical'}
# The Jungle Book storm -> {'meteorology'}
# The Jungle Book leader -> {'person'}
# The Jungle Book King -> {'history', 'person'}
# The Jungle Book jungle -> {'geography'}
# The Jungle Book panther -> {'biology', 'animals'}
# The Jungle Book volunteers -> {'military'}
# The Jungle Book python -> {'biology', 'animals'}
# The Jungle Book riverside -> {'geography', 'geology'}
# The Jungle Book tail -> {'animals', 'anatomy'}
# The Jungle Book morning -> {'time_period'}
# The Jungle Book mind -> {'psychology'}
# The Jungle Book vultures -> {'animals'}
# The Jungle Book water -> {'geography', 'chemistry'}
# The Jungle Book tiger -> {'person'}
# The Jungle Book orphan -> {'person'}
# The Jungle Book parents -> {'person'}
# The Jungle Book lightning -> {'electricity'}
# The Jungle Book branch -> {'administration'}
# The Jungle Book cubs -> {'person'}
# The Jungle Book Colonel -> {'military'}
# The Jungle Book mother -> {'person'}
# The Jungle Book panics -> {'psychological_features'}
# The Jungle Book palace -> {'buildings'}
# The Jungle Book monkeys -> {'animals'}
# The Jungle Book Council -> {'administration'}
# The Jungle Book Bengal -> {'geography'}
# The Jungle Book jungles -> {'geography'}
# The Jungle Book orangutan -> {'biology', 'animals'}
# The Jungle Book Khan -> {'history'}
# The Jungle Book bear -> {'biology', 'animals'}
# The Jungle Book India -> {'geography', 'economy', 'commerce'}
# The Jungle Book pot -> {'gastronomy'}
# The Jungle Book wolf -> {'biology', 'animals'}
# The Jungle Book outcast -> {'person'}
# The Jungle Book tree -> {'plants'}
# The Jungle Book years -> {'time_period'}
# The Jungle Book fun -> {'free_time'}
# The Jungle Book sloth -> {'psychological_features'}
# The Jungle Book elephant -> {'biology', 'animals'}
# The Jungle Book patrol -> {'military'}
# The Jungle Book night -> {'time_period'}
# The Jungle Book Rock -> {'geology'}
# The Jungle Book
# Counter({'person': 9,
#          'animals': 9,
#          'geography': 6,
#          'biology': 6,
#          'military': 3,
#          'time_period': 3,
#          'history': 2,
#          'geology': 2,
#          'administration': 2,
#          'psychological_features': 2,
#          'nautical': 1,
#          'meteorology': 1,
#          'anatomy': 1,
#          'psychology': 1,
#          'chemistry': 1,
#          'electricity': 1,
#          'buildings': 1,
#          'economy': 1,
#          'commerce': 1,
#          'gastronomy': 1,
#          'plants': 1,
#          'free_time': 1})
# One Hundred and One Dalmatians van -> {'art'}
# One Hundred and One Dalmatians horse -> {'biology', 'animals'}
# One Hundred and One Dalmatians ravine -> {'geography', 'geology'}
# One Hundred and One Dalmatians mate -> {'person', 'nautical'}
# One Hundred and One Dalmatians Horace -> {'literature'}
# One Hundred and One Dalmatians Christmas -> {'religion'}
# One Hundred and One Dalmatians cat -> {'animals'}
# One Hundred and One Dalmatians stores -> {'buildings', 'town_planning'}
# One Hundred and One Dalmatians Hall -> {'buildings'}
# One Hundred and One Dalmatians henchmen -> {'law'}
# One Hundred and One Dalmatians Twilight -> {'time_period'}
# One Hundred and One Dalmatians weeks -> {'time_period'}
# One Hundred and One Dalmatians Dalmatian -> {'geography'}
# One Hundred and One Dalmatians message -> {'telecommunication'}
# One Hundred and One Dalmatians Winter -> {'time_period'}
# One Hundred and One Dalmatians police -> {'administration', 'military'}
# One Hundred and One Dalmatians soot -> {'chemistry'}
# One Hundred and One Dalmatians animals -> {'biology', 'animals'}
# One Hundred and One Dalmatians skin -> {'anatomy'}
# One Hundred and One Dalmatians television -> {'telecommunication'}
# One Hundred and One Dalmatians Jasper -> {'jewellery', 'chemistry'}
# One Hundred and One Dalmatians companions -> {'person'}
# One Hundred and One Dalmatians money -> {'money'}
# One Hundred and One Dalmatians dogs -> {'biology', 'animals'}
# One Hundred and One Dalmatians Yard -> {'metrology'}
# One Hundred and One Dalmatians Dalmatians -> {'geography'}
# One Hundred and One Dalmatians litter -> {'biology', 'animals'}
# One Hundred and One Dalmatians schoolmate -> {'school'}
# One Hundred and One Dalmatians canine -> {'anatomy'}
# One Hundred and One Dalmatians pets -> {'animals'}
# One Hundred and One Dalmatians vehicles -> {'transport'}
# One Hundred and One Dalmatians River -> {'geography', 'tourism'}
# One Hundred and One Dalmatians Sheepdog -> {'animals'}
# One Hundred and One Dalmatians water -> {'geography', 'chemistry'}
# One Hundred and One Dalmatians English -> {'linguistics'}
# One Hundred and One Dalmatians birth -> {'time_period'}
# One Hundred and One Dalmatians estate -> {'economy'}
# One Hundred and One Dalmatians door -> {'buildings', 'vehicles'}
# One Hundred and One Dalmatians Labradors -> {'administration', 'geography'}
# One Hundred and One Dalmatians coats -> {'fashion'}
# One Hundred and One Dalmatians adult -> {'person'}
# One Hundred and One Dalmatians hit -> {'baseball'}
# One Hundred and One Dalmatians compatriots -> {'politics'}
# One Hundred and One Dalmatians show -> {'free_time'}
# One Hundred and One Dalmatians family -> {'person'}
# One Hundred and One Dalmatians Colonel -> {'military'}
# One Hundred and One Dalmatians park -> {'tourism'}
# One Hundred and One Dalmatians town -> {'geography', 'town_planning'}
# One Hundred and One Dalmatians Old -> {'time_period'}
# One Hundred and One Dalmatians bark -> {'plants'}
# One Hundred and One Dalmatians sale -> {'commerce'}
# One Hundred and One Dalmatians house -> {'buildings', 'town_planning'}
# One Hundred and One Dalmatians fear -> {'psychological_features'}
# One Hundred and One Dalmatians London -> {'geography'}
# One Hundred and One Dalmatians country -> {'geography'}
# One Hundred and One Dalmatians dog -> {'biology', 'animals'}
# One Hundred and One Dalmatians plantation -> {'economy'}
# One Hundred and One Dalmatians nanny -> {'person'}
# One Hundred and One Dalmatians ice -> {'chemistry'}
# One Hundred and One Dalmatians Sergeant -> {'military'}
# One Hundred and One Dalmatians Pongo -> {'biology', 'animals'}
# One Hundred and One Dalmatians car -> {'transport', 'tourism'}
# One Hundred and One Dalmatians snow -> {'meteorology'}
# One Hundred and One Dalmatians Captain -> {'military'}
# One Hundred and One Dalmatians window -> {'buildings'}
# One Hundred and One Dalmatians word -> {'linguistics'}
# One Hundred and One Dalmatians love -> {'psychological_features'}
# One Hundred and One Dalmatians song -> {'music'}
# One Hundred and One Dalmatians night -> {'time_period'}
# One Hundred and One Dalmatians songwriter -> {'music'}
# One Hundred and One Dalmatians puppies -> {'animals'}
# One Hundred and One Dalmatians fur -> {'animals'}
# One Hundred and One Dalmatians
# Counter({'animals': 11,
#          'geography': 9,
#          'biology': 6,
#          'time_period': 6,
#          'person': 5,
#          'buildings': 5,
#          'military': 4,
#          'chemistry': 4,
#          'town_planning': 3,
#          'tourism': 3,
#          'telecommunication': 2,
#          'administration': 2,
#          'anatomy': 2,
#          'transport': 2,
#          'linguistics': 2,
#          'economy': 2,
#          'psychological_features': 2,
#          'music': 2,
#          'art': 1,
#          'geology': 1,
#          'nautical': 1,
#          'literature': 1,
#          'religion': 1,
#          'law': 1,
#          'jewellery': 1,
#          'money': 1,
#          'metrology': 1,
#          'school': 1,
#          'vehicles': 1,
#          'fashion': 1,
#          'baseball': 1,
#          'politics': 1,
#          'free_time': 1,
#          'plants': 1,
#          'commerce': 1,
#          'meteorology': 1})
# The Sword in the Stone magic -> {'religion'}
# The Sword in the Stone friend -> {'person'}
# The Sword in the Stone strength -> {'quality'}
# The Sword in the Stone Wizards -> {'person'}
# The Sword in the Stone sword -> {'military'}
# The Sword in the Stone Christmas -> {'religion'}
# The Sword in the Stone Merlin -> {'literature', 'mythology'}
# The Sword in the Stone King -> {'history', 'person'}
# The Sword in the Stone teacher -> {'pedagogy'}
# The Sword in the Stone tournament -> {'sport'}
# The Sword in the Stone cheating -> {'sociology'}
# The Sword in the Stone lesson -> {'pedagogy'}
# The Sword in the Stone Years -> {'time_period'}
# The Sword in the Stone Archimedes -> {'mathematics', 'physics'}
# The Sword in the Stone room -> {'buildings'}
# The Sword in the Stone pet -> {'animals'}
# The Sword in the Stone Hobbs -> {'cricket'}
# The Sword in the Stone forest -> {'plants', 'biology'}
# The Sword in the Stone punishment -> {'law'}
# The Sword in the Stone castle -> {'buildings'}
# The Sword in the Stone sparrow -> {'biology', 'animals'}
# The Sword in the Stone century -> {'time_period'}
# The Sword in the Stone squire -> {'history', 'military'}
# The Sword in the Stone nemesis -> {'mythology'}
# The Sword in the Stone Bermuda -> {'geography'}
# The Sword in the Stone Sword -> {'military'}
# The Sword in the Stone throne -> {'furniture'}
# The Sword in the Stone Eve -> {'religion'}
# The Sword in the Stone orphan -> {'person'}
# The Sword in the Stone None -> {'time_period'}
# The Sword in the Stone churchyard -> {'town_planning'}
# The Sword in the Stone games -> {'sport'}
# The Sword in the Stone Stone -> {'geology'}
# The Sword in the Stone wizard -> {'person'}
# The Sword in the Stone Pendragon -> {'history'}
# The Sword in the Stone gravity -> {'physics'}
# The Sword in the Stone inscription -> {'literature'}
# The Sword in the Stone deer -> {'biology', 'animals'}
# The Sword in the Stone mumps -> {'medicine'}
# The Sword in the Stone ruling -> {'law'}
# The Sword in the Stone king -> {'history', 'person'}
# The Sword in the Stone owl -> {'biology', 'animals'}
# The Sword in the Stone form -> {'linguistics'}
# The Sword in the Stone squirrels -> {'biology', 'animals'}
# The Sword in the Stone father -> {'person'}
# The Sword in the Stone London -> {'geography'}
# The Sword in the Stone amends -> {'law', 'economy'}
# The Sword in the Stone inn -> {'buildings', 'town_planning', 'tourism'}
# The Sword in the Stone fish -> {'biology', 'animals'}
# The Sword in the Stone heir -> {'law', 'economy'}
# The Sword in the Stone tutor -> {'pedagogy'}
# The Sword in the Stone winner -> {'person'}
# The Sword in the Stone kitchen -> {'buildings'}
# The Sword in the Stone physics -> {'physics'}
# The Sword in the Stone dishes -> {'gastronomy'}
# The Sword in the Stone Arthur -> {'history', 'person'}
# The Sword in the Stone tree -> {'plants'}
# The Sword in the Stone prophecy -> {'occultism'}
# The Sword in the Stone witch -> {'occultism'}
# The Sword in the Stone brother -> {'person'}
# The Sword in the Stone resolves -> {'psychological_features'}
# The Sword in the Stone moat -> {'transport'}
# The Sword in the Stone education -> {'pedagogy'}
# The Sword in the Stone history -> {'time_period'}
# The Sword in the Stone war -> {'history', 'military'}
# The Sword in the Stone
# Counter({'person': 10,
#          'history': 6,
#          'animals': 6,
#          'biology': 6,
#          'military': 4,
#          'pedagogy': 4,
#          'time_period': 4,
#          'buildings': 4,
#          'law': 4,
#          'religion': 3,
#          'physics': 3,
#          'literature': 2,
#          'mythology': 2,
#          'sport': 2,
#          'plants': 2,
#          'geography': 2,
#          'town_planning': 2,
#          'economy': 2,
#          'occultism': 2,
#          'quality': 1,
#          'sociology': 1,
#          'mathematics': 1,
#          'cricket': 1,
#          'furniture': 1,
#          'geology': 1,
#          'medicine': 1,
#          'linguistics': 1,
#          'tourism': 1,
#          'gastronomy': 1,
#          'psychological_features': 1,
#          'transport': 1})
# Alice in Wonderland garden -> {'town_planning', 'agriculture'}
# Alice in Wonderland riverbank -> {'geography', 'geology'}
# Alice in Wonderland Hatter -> {'person'}
# Alice in Wonderland tea -> {'food'}
# Alice in Wonderland Caterpillar -> {'biology', 'animals'}
# Alice in Wonderland Hearts -> {'card'}
# Alice in Wonderland March -> {'time_period', 'metrology'}
# Alice in Wonderland King -> {'history', 'person'}
# Alice in Wonderland rock -> {'geology'}
# Alice in Wonderland adventure -> {'tourism'}
# Alice in Wonderland directions -> {'transport'}
# Alice in Wonderland flamingos -> {'biology', 'animals'}
# Alice in Wonderland characters -> {'literature'}
# Alice in Wonderland lesson -> {'pedagogy'}
# Alice in Wonderland Hare -> {'biology', 'animals'}
# Alice in Wonderland Norman -> {'music'}
# Alice in Wonderland sister -> {'person'}
# Alice in Wonderland Cat -> {'animals'}
# Alice in Wonderland headpiece -> {'racing', 'fashion'}
# Alice in Wonderland carrot -> {'plants'}
# Alice in Wonderland White -> {'anthropology'}
# Alice in Wonderland Drink -> {'food'}
# Alice in Wonderland woods -> {'plants', 'biology'}
# Alice in Wonderland castle -> {'buildings'}
# Alice in Wonderland guards -> {'person'}
# Alice in Wonderland biscuit -> {'food', 'chemistry'}
# Alice in Wonderland mushroom -> {'plants'}
# Alice in Wonderland courtroom -> {'buildings'}
# Alice in Wonderland courthouse -> {'buildings'}
# Alice in Wonderland Song -> {'music'}
# Alice in Wonderland beheading -> {'law'}
# Alice in Wonderland food -> {'food'}
# Alice in Wonderland Rabbit -> {'biology', 'animals'}
# Alice in Wonderland housemaid -> {'person'}
# Alice in Wonderland weed -> {'plants'}
# Alice in Wonderland want -> {'finance'}
# Alice in Wonderland door -> {'buildings', 'vehicles'}
# Alice in Wonderland butterfly -> {'entomology'}
# Alice in Wonderland distress -> {'psychological_features'}
# Alice in Wonderland inches -> {'metrology'}
# Alice in Wonderland execution -> {'law'}
# Alice in Wonderland gardeners -> {'agriculture'}
# Alice in Wonderland forces -> {'military'}
# Alice in Wonderland ones -> {'number'}
# Alice in Wonderland Queen -> {'entomology'}
# Alice in Wonderland rabbit -> {'biology', 'animals'}
# Alice in Wonderland party -> {'anthropology', 'history', 'sociology', 'politics'}
# Alice in Wonderland card -> {'card'}
# Alice in Wonderland cookie -> {'food', 'chemistry'}
# Alice in Wonderland days -> {'time_period'}
# Alice in Wonderland Dormouse -> {'biology', 'animals'}
# Alice in Wonderland present -> {'time_period'}
# Alice in Wonderland keyhole -> {'buildings', 'vehicles'}
# Alice in Wonderland house -> {'buildings', 'town_planning'}
# Alice in Wonderland watch -> {'metrology'}
# Alice in Wonderland trial -> {'law'}
# Alice in Wonderland Fed -> {'administration'}
# Alice in Wonderland pocket -> {'fashion'}
# Alice in Wonderland roses -> {'plants', 'biology'}
# Alice in Wonderland witnesses -> {'person', 'law'}
# Alice in Wonderland gloves -> {'fashion'}
# Alice in Wonderland trio -> {'number'}
# Alice in Wonderland game -> {'sport'}
# Alice in Wonderland film -> {'telecommunication', 'racing', 'sociology'}
# Alice in Wonderland prankster -> {'person'}
# Alice in Wonderland sea -> {'geography'}
# Alice in Wonderland Carpenter -> {'buildings', 'industry'}
# Alice in Wonderland shortcut -> {'transport'}
# Alice in Wonderland hedgehogs -> {'animals'}
# Alice in Wonderland waistcoat -> {'fashion'}
# Alice in Wonderland Dodo -> {'person'}
# Alice in Wonderland flowers -> {'plants'}
# Alice in Wonderland history -> {'time_period'}
# Alice in Wonderland song -> {'music'}
# Alice in Wonderland sobbing -> {'physiology'}
# Alice in Wonderland Walrus -> {'biology', 'animals'}
# Alice in Wonderland tears -> {'physiology'}
# Alice in Wonderland
# Counter({'biology': 9,
#          'animals': 9,
#          'person': 8,
#          'buildings': 7,
#          'plants': 6,
#          'food': 5,
#          'time_period': 4,
#          'fashion': 4,
#          'law': 4,
#          'metrology': 3,
#          'music': 3,
#          'town_planning': 2,
#          'agriculture': 2,
#          'geography': 2,
#          'geology': 2,
#          'card': 2,
#          'history': 2,
#          'transport': 2,
#          'racing': 2,
#          'anthropology': 2,
#          'chemistry': 2,
#          'vehicles': 2,
#          'entomology': 2,
#          'number': 2,
#          'sociology': 2,
#          'physiology': 2,
#          'tourism': 1,
#          'literature': 1,
#          'pedagogy': 1,
#          'finance': 1,
#          'psychological_features': 1,
#          'military': 1,
#          'politics': 1,
#          'administration': 1,
#          'sport': 1,
#          'telecommunication': 1,
#          'industry': 1})
# Cinderella garden -> {'town_planning', 'agriculture'}
# Cinderella horse -> {'biology', 'animals'}
# Cinderella Grand -> {'number'}
# Cinderella maid -> {'person'}
# Cinderella cat -> {'animals'}
# Cinderella design -> {'drawing'}
# Cinderella King -> {'history', 'person'}
# Cinderella attic -> {'buildings'}
# Cinderella floor -> {'buildings'}
# Cinderella friends -> {'person'}
# Cinderella coach -> {'sport'}
# Cinderella slippers -> {'fashion'}
# Cinderella Fairy -> {'mythology'}
# Cinderella midnight -> {'time_period'}
# Cinderella animal -> {'biology', 'animals'}
# Cinderella relief -> {'psychological_features'}
# Cinderella Prince -> {'heraldry'}
# Cinderella castle -> {'buildings'}
# Cinderella foot -> {'metrology'}
# Cinderella glass -> {'chemistry'}
# Cinderella guards -> {'person'}
# Cinderella stroll -> {'tourism'}
# Cinderella pets -> {'animals'}
# Cinderella mice -> {'animals'}
# Cinderella slipper -> {'fashion'}
# Cinderella stepsisters -> {'person'}
# Cinderella pumpkin -> {'plants', 'biology'}
# Cinderella horses -> {'biology', 'animals'}
# Cinderella parents -> {'person'}
# Cinderella coachman -> {'transport'}
# Cinderella dress -> {'fashion'}
# Cinderella area -> {'geography'}
# Cinderella accessories -> {'fashion'}
# Cinderella family -> {'person'}
# Cinderella spell -> {'psychology'}
# Cinderella mother -> {'person'}
# Cinderella ball -> {'play', 'sport'}
# Cinderella Gus -> {'geography'}
# Cinderella Godmother -> {'religion'}
# Cinderella necklace -> {'jewellery'}
# Cinderella scullery -> {'buildings'}
# Cinderella birds -> {'biology', 'animals'}
# Cinderella palace -> {'buildings'}
# Cinderella wedding -> {'sociology', 'religion'}
# Cinderella household -> {'person'}
# Cinderella royal -> {'industry', 'nautical'}
# Cinderella house -> {'buildings', 'town_planning'}
# Cinderella bedroom -> {'buildings'}
# Cinderella Duke -> {'heraldry', 'sociology'}
# Cinderella chime -> {'music'}
# Cinderella clock -> {'metrology'}
# Cinderella pocket -> {'fashion'}
# Cinderella spite -> {'psychological_features'}
# Cinderella horror -> {'psychological_features'}
# Cinderella gardens -> {'town_planning', 'agriculture'}
# Cinderella dog -> {'biology', 'animals'}
# Cinderella carriage -> {'railway', 'tourism'}
# Cinderella sash -> {'buildings'}
# Cinderella footman -> {'person'}
# Cinderella film -> {'telecommunication', 'racing', 'sociology'}
# Cinderella gown -> {'fashion'}
# Cinderella Bruno -> {'religion'}
# Cinderella son -> {'person'}
# Cinderella fall -> {'time_period'}
# Cinderella costume -> {'fashion'}
# Cinderella love -> {'psychological_features'}
# Cinderella Major -> {'military'}
# Cinderella stroke -> {'sport'}
# Cinderella tears -> {'physiology'}
# Cinderella
# Counter({'person': 11,
#          'animals': 8,
#          'buildings': 8,
#          'fashion': 7,
#          'biology': 6,
#          'psychological_features': 4,
#          'town_planning': 3,
#          'sport': 3,
#          'religion': 3,
#          'sociology': 3,
#          'agriculture': 2,
#          'time_period': 2,
#          'heraldry': 2,
#          'metrology': 2,
#          'tourism': 2,
#          'geography': 2,
#          'number': 1,
#          'drawing': 1,
#          'history': 1,
#          'mythology': 1,
#          'chemistry': 1,
#          'plants': 1,
#          'transport': 1,
#          'psychology': 1,
#          'play': 1,
#          'jewellery': 1,
#          'industry': 1,
#          'nautical': 1,
#          'music': 1,
#          'railway': 1,
#          'telecommunication': 1,
#          'racing': 1,
#          'military': 1,
#          'physiology': 1})
# Sleeping Beauty magic -> {'religion'}
# Sleeping Beauty celebrations -> {'sociology'}
# Sleeping Beauty friend -> {'person'}
# Sleeping Beauty sun -> {'astronomy'}
# Sleeping Beauty dragon -> {'mythology'}
# Sleeping Beauty Flora -> {'biology', 'animals', 'plants'}
# Sleeping Beauty sword -> {'military'}
# Sleeping Beauty Rose -> {'plants', 'biology'}
# Sleeping Beauty Aurora -> {'time_period'}
# Sleeping Beauty holiday -> {'free_time', 'tourism'}
# Sleeping Beauty King -> {'history', 'person'}
# Sleeping Beauty finger -> {'person', 'anatomy'}
# Sleeping Beauty color -> {'color'}
# Sleeping Beauty Briar -> {'plants'}
# Sleeping Beauty cottage -> {'buildings', 'tourism'}
# Sleeping Beauty animals -> {'biology', 'animals'}
# Sleeping Beauty room -> {'buildings'}
# Sleeping Beauty forest -> {'plants', 'biology'}
# Sleeping Beauty evening -> {'time_period'}
# Sleeping Beauty Prince -> {'heraldry'}
# Sleeping Beauty fairy -> {'mythology'}
# Sleeping Beauty christening -> {'religion'}
# Sleeping Beauty castle -> {'buildings'}
# Sleeping Beauty peasant -> {'person'}
# Sleeping Beauty kings -> {'history', 'person'}
# Sleeping Beauty Sword -> {'military'}
# Sleeping Beauty prince -> {'heraldry'}
# Sleeping Beauty spinning -> {'industry', 'art'}
# Sleeping Beauty Princess -> {'heraldry'}
# Sleeping Beauty godmothers -> {'religion'}
# Sleeping Beauty parents -> {'person'}
# Sleeping Beauty fairies -> {'mythology'}
# Sleeping Beauty guardians -> {'person'}
# Sleeping Beauty spell -> {'psychology'}
# Sleeping Beauty Dream -> {'physiology'}
# Sleeping Beauty Queen -> {'entomology'}
# Sleeping Beauty party -> {'anthropology', 'history', 'sociology', 'politics'}
# Sleeping Beauty birthday -> {'time_period'}
# Sleeping Beauty bed -> {'furniture'}
# Sleeping Beauty wheel -> {'mechanics', 'transport'}
# Sleeping Beauty ballroom -> {'buildings', 'town_planning'}
# Sleeping Beauty father -> {'person'}
# Sleeping Beauty Fauna -> {'biology', 'animals', 'plants'}
# Sleeping Beauty guests -> {'person'}
# Sleeping Beauty strangers -> {'person'}
# Sleeping Beauty voice -> {'acoustics'}
# Sleeping Beauty dance -> {'dance'}
# Sleeping Beauty berries -> {'plants', 'chemistry', 'gastronomy'}
# Sleeping Beauty princess -> {'heraldry'}
# Sleeping Beauty gown -> {'fashion'}
# Sleeping Beauty years -> {'time_period'}
# Sleeping Beauty son -> {'person'}
# Sleeping Beauty surprise -> {'psychological_features'}
# Sleeping Beauty spindle -> {'biology'}
# Sleeping Beauty Virtue -> {'quality'}
# Sleeping Beauty Shield -> {'history', 'military'}
# Sleeping Beauty daughter -> {'person'}
# Sleeping Beauty slumber -> {'physiology'}
# Sleeping Beauty love -> {'psychological_features'}
# Sleeping Beauty song -> {'music'}
# Sleeping Beauty grace -> {'religion'}
# Sleeping Beauty
# Counter({'person': 12,
#          'biology': 6,
#          'plants': 6,
#          'religion': 4,
#          'time_period': 4,
#          'history': 4,
#          'buildings': 4,
#          'heraldry': 4,
#          'mythology': 3,
#          'animals': 3,
#          'military': 3,
#          'sociology': 2,
#          'tourism': 2,
#          'physiology': 2,
#          'psychological_features': 2,
#          'astronomy': 1,
#          'free_time': 1,
#          'anatomy': 1,
#          'color': 1,
#          'industry': 1,
#          'art': 1,
#          'psychology': 1,
#          'entomology': 1,
#          'anthropology': 1,
#          'politics': 1,
#          'furniture': 1,
#          'mechanics': 1,
#          'transport': 1,
#          'town_planning': 1,
#          'acoustics': 1,
#          'dance': 1,
#          'chemistry': 1,
#          'gastronomy': 1,
#          'fashion': 1,
#          'quality': 1,
#          'music': 1})
# Lady and the Tramp strays -> {'animals'}
# Lady and the Tramp barks -> {'plants'}
# Lady and the Tramp spaniel -> {'animals', 'hunting'}
# Lady and the Tramp shop -> {'buildings', 'town_planning'}
# Lady and the Tramp closet -> {'furniture'}
# Lady and the Tramp cocker -> {'animals', 'hunting'}
# Lady and the Tramp beaver -> {'animals'}
# Lady and the Tramp Christmas -> {'religion'}
# Lady and the Tramp nursery -> {'buildings'}
# Lady and the Tramp bloodhound -> {'animals', 'hunting'}
# Lady and the Tramp stray -> {'animals'}
# Lady and the Tramp muzzle -> {'military'}
# Lady and the Tramp hens -> {'animals'}
# Lady and the Tramp Tramp -> {'person'}
# Lady and the Tramp pound -> {'metrology'}
# Lady and the Tramp daughters -> {'person'}
# Lady and the Tramp punishment -> {'law'}
# Lady and the Tramp evening -> {'time_period'}
# Lady and the Tramp dogs -> {'biology', 'animals'}
# Lady and the Tramp catcher -> {'play', 'baseball'}
# Lady and the Tramp dinner -> {'gastronomy'}
# Lady and the Tramp litter -> {'biology', 'animals'}
# Lady and the Tramp yard -> {'metrology'}
# Lady and the Tramp past -> {'time_period'}
# Lady and the Tramp rat -> {'animals'}
# Lady and the Tramp Jock -> {'sport'}
# Lady and the Tramp Pekingese -> {'animals'}
# Lady and the Tramp vacation -> {'free_time', 'tourism'}
# Lady and the Tramp year -> {'time_period'}
# Lady and the Tramp cats -> {'animals'}
# Lady and the Tramp horses -> {'biology', 'animals'}
# Lady and the Tramp birth -> {'time_period'}
# Lady and the Tramp leg -> {'anatomy'}
# Lady and the Tramp Missouri -> {'geography'}
# Lady and the Tramp Bull -> {'animals'}
# Lady and the Tramp baby -> {'person'}
# Lady and the Tramp taxi -> {'transport', 'military', 'town_planning', 'tourism'}
# Lady and the Tramp backyard -> {'buildings'}
# Lady and the Tramp locks -> {'buildings', 'vehicles'}
# Lady and the Tramp Darling -> {'person'}
# Lady and the Tramp hometown -> {'geography'}
# Lady and the Tramp terrier -> {'animals', 'hunting'}
# Lady and the Tramp head -> {'animals', 'anatomy'}
# Lady and the Tramp family -> {'person'}
# Lady and the Tramp charge -> {'law'}
# Lady and the Tramp town -> {'geography', 'town_planning'}
# Lady and the Tramp wagon -> {'transport'}
# Lady and the Tramp teeth -> {'person', 'anatomy'}
# Lady and the Tramp Aunt -> {'person'}
# Lady and the Tramp restaurant -> {'buildings', 'town_planning', 'commerce', 'tourism'}
# Lady and the Tramp infant -> {'person'}
# Lady and the Tramp basement -> {'buildings'}
# Lady and the Tramp behavior -> {'psychology'}
# Lady and the Tramp house -> {'buildings', 'town_planning'}
# Lady and the Tramp zoo -> {'tourism'}
# Lady and the Tramp mutt -> {'animals'}
# Lady and the Tramp owners -> {'economy', 'commerce'}
# Lady and the Tramp guests -> {'person'}
# Lady and the Tramp collar -> {'fashion'}
# Lady and the Tramp bulldog -> {'animals'}
# Lady and the Tramp dog -> {'biology', 'animals'}
# Lady and the Tramp girlfriends -> {'person'}
# Lady and the Tramp trio -> {'number'}
# Lady and the Tramp Dear -> {'person'}
# Lady and the Tramp farmyard -> {'animal_husbandry'}
# Lady and the Tramp puppy -> {'animals'}
# Lady and the Tramp fun -> {'free_time'}
# Lady and the Tramp son -> {'person'}
# Lady and the Tramp love -> {'psychological_features'}
# Lady and the Tramp puppies -> {'animals'}
# Lady and the Tramp matter -> {'physics'}
# Lady and the Tramp
# Counter({'animals': 21,
#          'person': 12,
#          'buildings': 7,
#          'town_planning': 5,
#          'hunting': 4,
#          'time_period': 4,
#          'biology': 4,
#          'tourism': 4,
#          'anatomy': 3,
#          'geography': 3,
#          'military': 2,
#          'metrology': 2,
#          'law': 2,
#          'free_time': 2,
#          'transport': 2,
#          'commerce': 2,
#          'plants': 1,
#          'furniture': 1,
#          'religion': 1,
#          'play': 1,
#          'baseball': 1,
#          'gastronomy': 1,
#          'sport': 1,
#          'vehicles': 1,
#          'psychology': 1,
#          'economy': 1,
#          'fashion': 1,
#          'number': 1,
#          'animal_husbandry': 1,
#          'psychological_features': 1,
#          'physics': 1})
# Peter Pan children -> {'person'}
# Peter Pan mate -> {'person', 'nautical'}
# Peter Pan friend -> {'person'}
# Peter Pan pixie -> {'folklore', 'mythology'}
# Peter Pan Lily -> {'plants', 'biology'}
# Peter Pan Indians -> {'anthropology', 'geography'}
# Peter Pan pirate -> {'law'}
# Peter Pan brothers -> {'person'}
# Peter Pan childhood -> {'time_period'}
# Peter Pan nursery -> {'buildings'}
# Peter Pan Lost -> {'medicine'}
# Peter Pan plank -> {'buildings'}
# Peter Pan sister -> {'person'}
# Peter Pan Land -> {'economy'}
# Peter Pan antics -> {'free_time'}
# Peter Pan Bell -> {'acoustics'}
# Peter Pan terror -> {'psychological_features'}
# Peter Pan Mary -> {'person', 'religion'}
# Peter Pan parents -> {'person'}
# Peter Pan Tiger -> {'person'}
# Peter Pan jealousy -> {'psychological_features'}
# Peter Pan bomb -> {'atomic_physic', 'military'}
# Peter Pan Darling -> {'person'}
# Peter Pan chief -> {'person'}
# Peter Pan party -> {'anthropology', 'history', 'sociology', 'politics'}
# Peter Pan Chief -> {'person'}
# Peter Pan John -> {'buildings'}
# Peter Pan wait -> {'time_period'}
# Peter Pan George -> {'person', 'mythology'}
# Peter Pan London -> {'geography'}
# Peter Pan hand -> {'person', 'anatomy'}
# Peter Pan island -> {'geography', 'tourism'}
# Peter Pan pirates -> {'law'}
# Peter Pan combat -> {'history', 'military'}
# Peter Pan crew -> {'nautical'}
# Peter Pan Peter -> {'religion'}
# Peter Pan adventures -> {'tourism'}
# Peter Pan Captain -> {'military'}
# Peter Pan window -> {'buildings'}
# Peter Pan crocodile -> {'biology', 'animals'}
# Peter Pan Darlings -> {'person'}
# Peter Pan daughter -> {'person'}
# Peter Pan ship -> {'economy', 'nautical'}
# Peter Pan night -> {'time_period'}
# Peter Pan Pan -> {'gastronomy'}
# Peter Pan lair -> {'geography'}
# Peter Pan tribe -> {'anthropology'}
# Peter Pan
# Counter({'person': 15,
#          'geography': 4,
#          'buildings': 4,
#          'nautical': 3,
#          'anthropology': 3,
#          'time_period': 3,
# ...
# Counter({'person': 9,
#          'animals': 8,
#          'biology': 5,
#          'time_period': 5,
#          'psychological_features': 5,
#          'anatomy': 4,
#          'religion': 3,
#          'play': 3,
#          'transport': 3,
#          'chemistry': 3,
#          'tourism': 3,
#          'buildings': 3,
#          'administration': 2,
#          'law': 2,
#          'telecommunication': 2,
#          'economy': 2,
#          'history': 2,
#          'astronomy': 2,
#          'commerce': 2,
#          'gastronomy': 2,
#          'military': 2,
#          'town_planning': 2,
#          'art': 1,
#          'medicine': 1,
#          'psychology': 1,
#          'furniture': 1,
#          'enterprise': 1,
#          'number': 1,
#          'literature': 1,
#          'anthropology': 1,
#          'sociology': 1,
#          'politics': 1,
#          'atomic_physic': 1,
#          'exchange': 1,
#          'computer_science': 1,
#          'electronics': 1,
#          'electrotechnology': 1,
#          'metrology': 1,
#          'physics': 1,
#          'banking': 1,
#          'sport': 1,
#          'publishing': 1})
# Mulan General -> {'history', 'military'}
# Mulan conscription -> {'military'}
# Mulan hair -> {'anatomy'}
# Mulan recruits -> {'military'}
# Mulan dragon -> {'mythology'}
# Mulan sword -> {'military'}
# Mulan leader -> {'person'}
# Mulan crest -> {'geography'}
# Mulan city -> {'administration', 'geography', 'town_planning'}
# Mulan inhabitants -> {'geography'}
# Mulan helmet -> {'history', 'military'}
# Mulan instructions -> {'publishing'}
# Mulan law -> {'law'}
# Mulan mobilization -> {'military'}
# Mulan rocket -> {'transport'}
# Mulan roof -> {'buildings'}
# Mulan Shan -> {'linguistics'}
# Mulan invaders -> {'person'}
# Mulan dinner -> {'gastronomy'}
# Mulan wound -> {'medicine'}
# Mulan Emperor -> {'history', 'person'}
# Mulan China -> {'geography'}
# Mulan chest -> {'anatomy'}
# Mulan strikes -> {'sociology'}
# Mulan Huns -> {'history'}
# Mulan fireworks -> {'atomic_physic', 'chemistry'}
# Mulan armor -> {'history', 'military'}
# Mulan parent -> {'person'}
# Mulan judgement -> {'law'}
# Mulan invitation -> {'post'}
# Mulan emperor -> {'history', 'person'}
# Mulan family -> {'person'}
# Mulan advisor -> {'person'}
# Mulan warriors -> {'military'}
# Mulan mountains -> {'geography', 'geology'}
# Mulan palace -> {'buildings'}
# Mulan explosion -> {'military'}
# Mulan Wall -> {'buildings'}
# Mulan celebration -> {'sociology'}
# Mulan camp -> {'buildings', 'military'}
# Mulan troops -> {'military'}
# Mulan Ling -> {'plants'}
# Mulan father -> {'person'}
# Mulan men -> {'economy'}
# Mulan combat -> {'history', 'military'}
# Mulan veteran -> {'military'}
# Mulan Hun -> {'history'}
# Mulan army -> {'military'}
# Mulan Captain -> {'military'}
# Mulan cannon -> {'military'}
# Mulan resolves -> {'psychological_features'}
# Mulan avalanche -> {'transport', 'geology'}
# Mulan stone -> {'geology'}
# Mulan encampment -> {'tourism'}
# Mulan health -> {'medicine'}
# Mulan guardian -> {'person'}
# Mulan war -> {'history', 'military'}
# Mulan
# Counter({'military': 17,
#          'history': 9,
#          'person': 9,
#          'geography': 5,
#          'buildings': 4,
#          'geology': 3,
#          'anatomy': 2,
#          'law': 2,
#          'transport': 2,
#          'medicine': 2,
#          'sociology': 2,
#          'mythology': 1,
#          'administration': 1,
#          'town_planning': 1,
#          'publishing': 1,
#          'linguistics': 1,
#          'gastronomy': 1,
#          'atomic_physic': 1,
#          'chemistry': 1,
#          'post': 1,
#          'plants': 1,
#          'economy': 1,
#          'psychological_features': 1,
#          'tourism': 1})
# DuckTales the Movie Treasure of the Lost Lamp children -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp magic -> {'religion'}
# DuckTales the Movie Treasure of the Lost Lamp friend -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp wish -> {'psychological_features'}
# DuckTales the Movie Treasure of the Lost Lamp things -> {'economy'}
# DuckTales the Movie Treasure of the Lost Lamp Woodchuck -> {'animals'}
# DuckTales the Movie Treasure of the Lost Lamp friends -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp value -> {'number', 'mathematics'}
# DuckTales the Movie Treasure of the Lost Lamp transport -> {'transport'}
# DuckTales the Movie Treasure of the Lost Lamp room -> {'buildings'}
# DuckTales the Movie Treasure of the Lost Lamp mansion -> {'astronomy', 'astrology'}
# DuckTales the Movie Treasure of the Lost Lamp thief -> {'law'}
# DuckTales the Movie Treasure of the Lost Lamp pig -> {'biology', 'animals'}
# DuckTales the Movie Treasure of the Lost Lamp wishes -> {'psychological_features'}
# DuckTales the Movie Treasure of the Lost Lamp animal -> {'biology', 'animals'}
# DuckTales the Movie Treasure of the Lost Lamp money -> {'money'}
# DuckTales the Movie Treasure of the Lost Lamp pants -> {'fashion'}
# DuckTales the Movie Treasure of the Lost Lamp slingshot -> {'play'}
# DuckTales the Movie Treasure of the Lost Lamp Pompeii -> {'geography', 'archaeology'}
# DuckTales the Movie Treasure of the Lost Lamp gravy -> {'gastronomy'}
# DuckTales the Movie Treasure of the Lost Lamp spots -> {'medicine'}
# DuckTales the Movie Treasure of the Lost Lamp Money -> {'money'}
# DuckTales the Movie Treasure of the Lost Lamp travels -> {'tourism'}
# DuckTales the Movie Treasure of the Lost Lamp earth -> {'astronomy'}
# DuckTales the Movie Treasure of the Lost Lamp Collie -> {'animals'}
# DuckTales the Movie Treasure of the Lost Lamp chest -> {'anatomy'}
# DuckTales the Movie Treasure of the Lost Lamp vacation -> {'free_time', 'tourism'}
# DuckTales the Movie Treasure of the Lost Lamp trousers -> {'fashion'}
# DuckTales the Movie Treasure of the Lost Lamp talisman -> {'folklore'}
# DuckTales the Movie Treasure of the Lost Lamp centuries -> {'time_period'}
# DuckTales the Movie Treasure of the Lost Lamp griffin -> {'mythology'}
# DuckTales the Movie Treasure of the Lost Lamp baby -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp wind -> {'meteorology'}
# DuckTales the Movie Treasure of the Lost Lamp sorcerer -> {'occultism'}
# DuckTales the Movie Treasure of the Lost Lamp robe -> {'fashion'}
# DuckTales the Movie Treasure of the Lost Lamp family -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp ball -> {'play', 'sport'}
# DuckTales the Movie Treasure of the Lost Lamp sundae -> {'gastronomy'}
# DuckTales the Movie Treasure of the Lost Lamp pyramid -> {'geometry'}
# DuckTales the Movie Treasure of the Lost Lamp Baba -> {'food', 'chemistry'}
# DuckTales the Movie Treasure of the Lost Lamp Days -> {'time_period'}
# DuckTales the Movie Treasure of the Lost Lamp house -> {'buildings', 'town_planning'}
# DuckTales the Movie Treasure of the Lost Lamp cream -> {'sociology'}
# DuckTales the Movie Treasure of the Lost Lamp fortress -> {'military'}
# DuckTales the Movie Treasure of the Lost Lamp sand -> {'geology'}
# DuckTales the Movie Treasure of the Lost Lamp forms -> {'linguistics'}
# DuckTales the Movie Treasure of the Lost Lamp air -> {'physics'}
# DuckTales the Movie Treasure of the Lost Lamp hand -> {'person', 'anatomy'}
# DuckTales the Movie Treasure of the Lost Lamp pocket -> {'fashion'}
# DuckTales the Movie Treasure of the Lost Lamp Scrooge -> {'person', 'banking'}
# DuckTales the Movie Treasure of the Lost Lamp East -> {'geology'}
# DuckTales the Movie Treasure of the Lost Lamp boat -> {'tourism', 'nautical'}
# DuckTales the Movie Treasure of the Lost Lamp ice -> {'chemistry'}
# DuckTales the Movie Treasure of the Lost Lamp clothes -> {'fashion'}
# DuckTales the Movie Treasure of the Lost Lamp toys -> {'play'}
# DuckTales the Movie Treasure of the Lost Lamp Gene -> {'biology', 'chemistry'}
# DuckTales the Movie Treasure of the Lost Lamp scout -> {'person'}
# DuckTales the Movie Treasure of the Lost Lamp elephant -> {'biology', 'animals'}
# DuckTales the Movie Treasure of the Lost Lamp Atlantis -> {'literature', 'mythology'}
# DuckTales the Movie Treasure of the Lost Lamp Society -> {'anthropology'}
# DuckTales the Movie Treasure of the Lost Lamp night -> {'time_period'}
# DuckTales the Movie Treasure of the Lost Lamp Dijon -> {'geography'}
# DuckTales the Movie Treasure of the Lost Lamp bird -> {'biology', 'animals'}
# DuckTales the Movie Treasure of the Lost Lamp
# Counter({'person': 8,
#          'animals': 6,
#          'biology': 5,
#          'fashion': 5,
#          'play': 3,
#          'tourism': 3,
#          'time_period': 3,
#          'chemistry': 3,
#          'psychological_features': 2,
#          'buildings': 2,
#          'astronomy': 2,
#          'money': 2,
#          'geography': 2,
#          'gastronomy': 2,
#          'anatomy': 2,
#          'mythology': 2,
#          'geology': 2,
#          'religion': 1,
#          'economy': 1,
#          'number': 1,
#          'mathematics': 1,
#          'transport': 1,
#          'astrology': 1,
#          'law': 1,
#          'archaeology': 1,
#          'medicine': 1,
#          'free_time': 1,
#          'folklore': 1,
#          'meteorology': 1,
#          'occultism': 1,
#          'sport': 1,
#          'geometry': 1,
#          'food': 1,
#          'town_planning': 1,
#          'sociology': 1,
#          'military': 1,
#          'linguistics': 1,
#          'physics': 1,
#          'banking': 1,
#          'nautical': 1,
#          'literature': 1,
#          'anthropology': 1})
# Tarzan mate -> {'person', 'nautical'}
# Tarzan stowaway -> {'transport'}
# Tarzan guide -> {'person'}
# Tarzan wish -> {'psychological_features'}
# Tarzan leader -> {'person'}
# Tarzan Porters -> {'tourism'}
# Tarzan team -> {'sport'}
# Tarzan Professor -> {'university', 'school'}
# Tarzan jungle -> {'geography'}
# Tarzan animals -> {'biology', 'animals'}
# Tarzan Archimedes -> {'mathematics', 'physics'}
# Tarzan successor -> {'person'}
# Tarzan feelings -> {'psychological_features'}
# Tarzan hunter -> {'hunting'}
# Tarzan projector -> {'optics'}
# Tarzan century -> {'time_period'}
# Tarzan tour -> {'tourism'}
# Tarzan savage -> {'anthropology', 'history'}
# Tarzan gorillas -> {'biology', 'animals'}
# Tarzan machete -> {'military'}
# Tarzan past -> {'time_period'}
# Tarzan interest -> {'psychology'}
# Tarzan suit -> {'law'}
# Tarzan vines -> {'plants'}
# Tarzan Porter -> {'tourism'}
# Tarzan rainforest -> {'geography'}
# Tarzan baby -> {'person'}
# Tarzan adult -> {'person'}
# Tarzan gorilla -> {'biology', 'animals'}
# Tarzan area -> {'geography'}
# Tarzan family -> {'person'}
# Tarzan battle -> {'history', 'military'}
# Tarzan baboon -> {'animals'}
# Tarzan child -> {'person'}
# Tarzan months -> {'time_period'}
# Tarzan shipwreck -> {'nautical'}
# Tarzan slide -> {'pure_science'}
# Tarzan infant -> {'person'}
# Tarzan camp -> {'buildings', 'military'}
# Tarzan trees -> {'plants'}
# Tarzan spear -> {'military'}
# Tarzan father -> {'person'}
# Tarzan troop -> {'military'}
# Tarzan throat -> {'anatomy'}
# Tarzan coast -> {'geology'}
# Tarzan shotgun -> {'military'}
# Tarzan garner -> {'commerce'}
# Tarzan leopard -> {'animals'}
# Tarzan trio -> {'number'}
# Tarzan tree -> {'plants'}
# Tarzan son -> {'person'}
# Tarzan civilization -> {'anthropology'}
# Tarzan elephant -> {'biology', 'animals'}
# Tarzan daughter -> {'person'}
# Tarzan ship -> {'economy', 'nautical'}
# Tarzan vine -> {'plants'}
# Tarzan branches -> {'administration'}
# Tarzan explorers -> {'history'}
# Tarzan
# Counter({'person': 12,
#          'animals': 6,
#          'military': 6,
#          'biology': 4,
#          'plants': 4,
#          'nautical': 3,
#          'tourism': 3,
#          'geography': 3,
#          'time_period': 3,
#          'history': 3,
#          'psychological_features': 2,
#          'anthropology': 2,
#          'transport': 1,
#          'sport': 1,
#          'university': 1,
#          'school': 1,
#          'mathematics': 1,
#          'physics': 1,
#          'hunting': 1,
#          'optics': 1,
#          'psychology': 1,
#          'law': 1,
#          'pure_science': 1,
#          'buildings': 1,
#          'anatomy': 1,
#          'geology': 1,
#          'commerce': 1,
#          'number': 1,
#          'economy': 1,
#          'administration': 1})
# Snow White and the Seven Dwarfs children -> {'person'}
# Snow White and the Seven Dwarfs maid -> {'person'}
# Snow White and the Seven Dwarfs chairs -> {'furniture'}
# Snow White and the Seven Dwarfs jewels -> {'jewellery'}
# Snow White and the Seven Dwarfs cliff -> {'geology'}
# Snow White and the Seven Dwarfs potion -> {'food'}
# Snow White and the Seven Dwarfs cottage -> {'buildings', 'tourism'}
# Snow White and the Seven Dwarfs animals -> {'biology', 'animals'}
# Snow White and the Seven Dwarfs room -> {'buildings'}
# Snow White and the Seven Dwarfs forest -> {'plants', 'biology'}
# Snow White and the Seven Dwarfs pig -> {'biology', 'animals'}
# Snow White and the Seven Dwarfs Prince -> {'heraldry'}
# Snow White and the Seven Dwarfs mirror -> {'furniture'}
# Snow White and the Seven Dwarfs singing -> {'music'}
# Snow White and the Seven Dwarfs dining -> {'physiology'}
# Snow White and the Seven Dwarfs White -> {'anthropology'}
# Snow White and the Seven Dwarfs castle -> {'buildings'}
# Snow White and the Seven Dwarfs woods -> {'plants', 'biology'}
# Snow White and the Seven Dwarfs glass -> {'chemistry'}
# Snow White and the Seven Dwarfs intruder -> {'person'}
# Snow White and the Seven Dwarfs Mirror -> {'furniture'}
# Snow White and the Seven Dwarfs huntsman -> {'hunting'}
# Snow White and the Seven Dwarfs movie -> {'telecommunication', 'racing', 'sociology'}
# Snow White and the Seven Dwarfs Magic -> {'religion'}
# Snow White and the Seven Dwarfs prince -> {'heraldry'}
# Snow White and the Seven Dwarfs hag -> {'person'}
# Snow White and the Seven Dwarfs year -> {'time_period'}
# Snow White and the Seven Dwarfs woodland -> {'geography'}
# Snow White and the Seven Dwarfs forgiveness -> {'psychological_features'}
# Snow White and the Seven Dwarfs land -> {'economy'}
# Snow White and the Seven Dwarfs ground -> {'geography'}
# Snow White and the Seven Dwarfs boulder -> {'geology'}
# Snow White and the Seven Dwarfs lightning -> {'electricity'}
# Snow White and the Seven Dwarfs adult -> {'person'}
# Snow White and the Seven Dwarfs spell -> {'psychology'}
# Snow White and the Seven Dwarfs poison -> {'medicine', 'chemistry'}
# Snow White and the Seven Dwarfs Queen -> {'entomology'}
# Snow White and the Seven Dwarfs scullery -> {'buildings'}
# Snow White and the Seven Dwarfs sleep -> {'physiology'}
# Snow White and the Seven Dwarfs apple -> {'plants', 'chemistry', 'gastronomy'}
# Snow White and the Seven Dwarfs beds -> {'furniture'}
# Snow White and the Seven Dwarfs meets -> {'sport'}
# Snow White and the Seven Dwarfs house -> {'buildings', 'town_planning'}
# Snow White and the Seven Dwarfs watch -> {'metrology'}
# Snow White and the Seven Dwarfs Snow -> {'meteorology'}
# Snow White and the Seven Dwarfs dwarfs -> {'person'}
# Snow White and the Seven Dwarfs music -> {'music'}
# Snow White and the Seven Dwarfs pretense -> {'sociology'}
# Snow White and the Seven Dwarfs dance -> {'dance'}
# Snow White and the Seven Dwarfs princess -> {'heraldry'}
# Snow White and the Seven Dwarfs years -> {'time_period'}
# Snow White and the Seven Dwarfs Doc -> {'medicine'}
# Snow White and the Seven Dwarfs slumber -> {'physiology'}
# Snow White and the Seven Dwarfs love -> {'psychological_features'}
# Snow White and the Seven Dwarfs Huntsman -> {'hunting'}
# Snow White and the Seven Dwarfs night -> {'time_period'}
# Snow White and the Seven Dwarfs creatures -> {'biology', 'animals'}
# Snow White and the Seven Dwarfs clearing -> {'geography'}
# Snow White and the Seven Dwarfs
# Counter({'person': 6,
#          'buildings': 5,
#          'biology': 5,
#          'furniture': 4,
#          'animals': 3,
#          'plants': 3,
#          'heraldry': 3,
#          'physiology': 3,
#          'chemistry': 3,
#          'time_period': 3,
#          'geography': 3,
#          'geology': 2,
#          'music': 2,
#          'hunting': 2,
#          'sociology': 2,
#          'psychological_features': 2,
#          'medicine': 2,
#          'jewellery': 1,
#          'food': 1,
#          'tourism': 1,
#          'anthropology': 1,
#          'telecommunication': 1,
#          'racing': 1,
#          'religion': 1,
#          'economy': 1,
#          'electricity': 1,
#          'psychology': 1,
#          'entomology': 1,
#          'gastronomy': 1,
#          'sport': 1,
#          'town_planning': 1,
#          'metrology': 1,
#          'meteorology': 1,
#          'dance': 1})

# %%
full_df = pd.DataFrame(columns=['1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000', '2010'])

for dom, decs in dict_all_domains.items():
    full_df.loc[dom] = [1 if (str(dec) in decs) else 0 for dec in range(1930, 2010 +1, 10)]
    
full_df.sort_index(inplace=True)

# %%
full_df
# Out:
#                        1930 1940 1950 1960 1970 1980 1990 2000 2010
# administration            0    0    0    1    1    0    0    0    0
# anatomy                   0    1    0    0    1    0    0    0    0
# animals                   1    1    1    1    1    1    1    1    1
# biology                   1    1    1    1    1    1    1    1    1
# buildings                 1    1    1    1    1    1    1    1    1
# chemistry                 1    0    0    0    0    0    0    1    1
# economy                   0    0    0    1    0    1    0    0    0
# furniture                 1    0    0    0    0    0    0    0    0
# geography                 1    1    1    1    1    1    1    1    1
# geology                   1    0    0    0    0    0    0    0    0
# heraldry                  1    0    0    0    0    0    0    0    0
# history                   0    0    1    1    1    0    1    0    1
# hunting                   1    0    0    0    0    0    0    0    0
# law                       0    0    1    0    1    1    1    1    1
# medicine                  1    0    0    0    0    0    0    0    0
# metrology                 0    0    1    0    0    0    0    0    0
# military                  0    0    1    1    1    1    1    0    1
# music                     1    0    0    0    0    0    0    0    0
# person                    1    1    1    1    1    1    1    1    1
# physiology                1    0    0    0    0    0    0    0    0
# plants                    1    1    1    0    0    0    0    0    0
# psychological_features    1    1    1    1    0    0    1    1    1
# religion                  0    0    1    0    0    0    0    0    0
# sociology                 1    1    0    0    0    0    0    0    0
# time_period               1    1    1    1    0    1    1    1    1
# tourism                   0    1    1    0    0    0    1    1    0
# town_planning             0    0    1    0    1    1    1    1    0
# transport                 0    0    0    0    1    1    0    1    1

# %%
full_df.to_csv(r"/Users/valeriaguttilla/Desktop/MASTER/PROGETTONE/ANALISI_TESTUALE/ANALISI TRAME/WordNet/analisi_risultati_WN/risultati.csv")
