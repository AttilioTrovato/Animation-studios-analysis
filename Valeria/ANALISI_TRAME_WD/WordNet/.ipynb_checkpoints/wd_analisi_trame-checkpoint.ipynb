# %%
import import_ipynb
import os
import pandas as pd
import gensim
from collections import Counter
from pprint import pprint

from WNDomains import WordNetDomains 
wnd = WordNetDomains(wordnet_home='.')

# %%
import nltk
from nltk.corpus import stopwords
en_stopwords = stopwords.words('english')

# %%
import spacy
nlp = spacy.load('en')

path= '../trame'

#domains_trama = set()  


list1=[1990, 2000, 2010]
dict_all_domains={}

for dirpath, dirnames, files in os.walk(path):
    dict_domains = {}
    
    for file in files:
        if file[0] == '.':
            continue

        domains_trama_all = set()
        counter = Counter()

        with open(dirpath+ "/" + file, 'r', encoding='Latin-1') as f:
            text = f.read()
            words = set(gensim.utils.simple_preprocess(text, deacc=True))
            words = words.difference(en_stopwords)
            doc = nlp(" ".join(words))
            words = [token.text if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in ['NOUN', 'VERB']]

            file=file.split('.')[0]
            decade=dirpath.split('/')[-1]

            for word in words:
                domain = wnd.get_domains(word, 'n', first_sense_only=True)
                for tmp_d in domain:
                    counter[tmp_d] += 1
                if len(domain) > 0:
                    print(file, word, '->', domain)
                domains_trama_all |= domain
                
            print(file)
            pprint(counter)

            for domain in domains_trama_all:
                if domain in dict_domains:
                    dict_domains[domain].append(file)
                else:
                    dict_domains[domain] = [file]

    for d in dict_domains:
        if decade in list1:
            if len(dict_domains[d]) >= (len(files)/2):
                if d in dict_all_domains:
                    dict_all_domains[d].append(decade)
                else:
                    dict_all_domains[d] = [decade]
        else:
            if len(dict_domains[d]) >= (len(files)*(0.75)):
                if d in dict_all_domains:
                    dict_all_domains[d].append(decade)
                else:
                    dict_all_domains[d] = [decade]
# Out:
# Hercules visit -> {'factotum'}
# Hercules saves -> {'sport'}
# Hercules return -> {'tax', 'law'}
# Hercules panic -> {'psychological_features'}
# Hercules minions -> {'economy'}
# Hercules capture -> {'factotum'}
# Hercules give -> {'physics'}
# Hercules exchange -> {'chemistry'}
# Hercules dies -> {'card'}
# Hercules friend -> {'person'}
# Hercules punches -> {'boxing'}
# Hercules infant -> {'person'}
# Hercules eve -> {'religion'}
# Hercules meg -> {'number'}
# Hercules heroes -> {'history'}
# Hercules monster -> {'factotum'}
# Hercules pull -> {'factotum'}
# Hercules turns -> {'transport'}
# Hercules friends -> {'person'}
# Hercules brother -> {'person'}
# Hercules telling -> {'literature'}
# Hercules hercules -> {'mythology'}
# Hercules cyclops -> {'mythology'}
# Hercules image -> {'factotum'}
# Hercules leave -> {'factotum'}
# Hercules holds -> {'factotum'}
# Hercules disappointments -> {'psychological_features'}
# Hercules property -> {'factotum'}
# Hercules river -> {'tourism', 'geography'}
# Hercules breaks -> {'factotum'}
# Hercules answers -> {'factotum'}
# Hercules love -> {'psychological_features'}
# Hercules earth -> {'astronomy'}
# Hercules minion -> {'economy'}
# Hercules underworld -> {'sociology'}
# Hercules welcome -> {'factotum'}
# Hercules stars -> {'astronomy'}
# Hercules turning -> {'transport'}
# Hercules kill -> {'sociology'}
# Hercules soul -> {'religion'}
# Hercules boys -> {'factotum'}
# Hercules strength -> {'quality'}
# Hercules goes -> {'time_period'}
# Hercules returns -> {'tax', 'law'}
# Hercules defeats -> {'factotum'}
# Hercules condition -> {'factotum'}
# Hercules satyr -> {'law'}
# Hercules parents -> {'person'}
# Hercules hero -> {'history'}
# Hercules kidnapping -> {'law'}
# Hercules wonders -> {'psychological_features'}
# Hercules growing -> {'biology'}
# Hercules citizens -> {'town_planning', 'politics'}
# Hercules training -> {'factotum'}
# Hercules damsel -> {'factotum'}
# Hercules help -> {'factotum'}
# Hercules temple -> {'religion', 'buildings'}
# Hercules ocean -> {'geography'}
# Hercules fly -> {'entomology', 'biology'}
# Hercules fame -> {'sociology'}
# Hercules willingness -> {'psychological_features'}
# Hercules climb -> {'geology', 'geography'}
# Hercules olympus -> {'geography'}
# Hercules offers -> {'factotum'}
# Hercules falls -> {'tourism', 'geography'}
# Hercules plots -> {'factotum'}
# Hercules disguise -> {'factotum'}
# Hercules pillar -> {'factotum'}
# Hercules fates -> {'mythology'}
# Hercules promise -> {'factotum'}
# Hercules tells -> {'archery', 'history'}
# Hercules find -> {'factotum'}
# Hercules saying -> {'linguistics'}
# Hercules rule -> {'factotum'}
# Hercules gods -> {'factotum'}
# Hercules save -> {'sport'}
# Hercules years -> {'time_period'}
# Hercules free -> {'factotum'}
# Hercules farmers -> {'factotum'}
# Hercules thebes -> {'geography'}
# Hercules souls -> {'religion'}
# Hercules king -> {'history', 'person'}
# Hercules rescues -> {'factotum'}
# Hercules working -> {'industry'}
# Hercules hostage -> {'law'}
# Hercules pain -> {'medicine'}
# Hercules releases -> {'commerce'}
# Hercules dream -> {'physiology'}
# Hercules outcast -> {'person'}
# Hercules head -> {'anatomy', 'animals'}
# Hercules found -> {'economy'}
# Hercules way -> {'factotum'}
# Hercules meet -> {'sport'}
# Hercules rulers -> {'metrology'}
# Hercules remove -> {'factotum'}
# Hercules immortality -> {'factotum'}
# Hercules feeding -> {'physiology'}
# Hercules life -> {'factotum'}
# Hercules train -> {'transport'}
# Hercules trains -> {'transport'}
# Hercules living -> {'factotum'}
# Hercules
# Counter({'factotum': 33,
#          'person': 7,
#          'geography': 6,
#          'law': 5,
#          'psychological_features': 5,
#          'religion': 4,
#          'history': 4,
#          'transport': 4,
#          'sport': 3,
#          'economy': 3,
#          'mythology': 3,
#          'sociology': 3,
#          'tax': 2,
#          'tourism': 2,
#          'astronomy': 2,
#          'time_period': 2,
#          'biology': 2,
#          'physiology': 2,
#          'physics': 1,
#          'chemistry': 1,
#          'card': 1,
#          'boxing': 1,
#          'number': 1,
#          'literature': 1,
#          'quality': 1,
#          'town_planning': 1,
#          'politics': 1,
#          'buildings': 1,
#          'entomology': 1,
#          'geology': 1,
#          'archery': 1,
#          'linguistics': 1,
#          'industry': 1,
#          'medicine': 1,
#          'commerce': 1,
#          'anatomy': 1,
#          'animals': 1,
#          'metrology': 1})
# Beauty and the Beast compassion -> {'psychological_features'}
# Beauty and the Beast wood -> {'plants', 'buildings'}
# Beauty and the Beast rush -> {'factotum'}
# Beauty and the Beast death -> {'factotum'}
# Beauty and the Beast escape -> {'factotum'}
# Beauty and the Beast chip -> {'factotum'}
# Beauty and the Beast dies -> {'card'}
# Beauty and the Beast warden -> {'administration', 'law'}
# Beauty and the Beast let -> {'politics'}
# Beauty and the Beast claims -> {'factotum'}
# Beauty and the Beast offer -> {'factotum'}
# Beauty and the Beast servants -> {'person'}
# Beauty and the Beast attempt -> {'factotum'}
# Beauty and the Beast advances -> {'factotum'}
# Beauty and the Beast sidekick -> {'person'}
# Beauty and the Beast seeks -> {'computer_science'}
# Beauty and the Beast town -> {'town_planning', 'geography'}
# Beauty and the Beast lost -> {'medicine'}
# Beauty and the Beast forest -> {'plants', 'biology'}
# Beauty and the Beast pack -> {'factotum'}
# Beauty and the Beast identity -> {'factotum'}
# Beauty and the Beast enchantress -> {'factotum'}
# Beauty and the Beast takes -> {'money'}
# Beauty and the Beast dungeon -> {'military'}
# Beauty and the Beast host -> {'person'}
# Beauty and the Beast place -> {'factotum'}
# Beauty and the Beast teacup -> {'factotum'}
# Beauty and the Beast wing -> {'entomology', 'anatomy'}
# Beauty and the Beast teapot -> {'gastronomy'}
# Beauty and the Beast dinner -> {'gastronomy'}
# Beauty and the Beast form -> {'linguistics'}
# Beauty and the Beast attentions -> {'factotum'}
# Beauty and the Beast using -> {'factotum'}
# Beauty and the Beast love -> {'psychological_features'}
# Beauty and the Beast shelter -> {'factotum'}
# Beauty and the Beast remembrance -> {'factotum'}
# Beauty and the Beast wounds -> {'medicine'}
# Beauty and the Beast plan -> {'factotum'}
# Beauty and the Beast horse -> {'biology', 'animals'}
# Beauty and the Beast led -> {'electrotechnology', 'electronics'}
# Beauty and the Beast wants -> {'finance'}
# Beauty and the Beast casts -> {'art'}
# Beauty and the Beast none -> {'time_period'}
# Beauty and the Beast household -> {'person'}
# Beauty and the Beast machine -> {'buildings'}
# Beauty and the Beast sanity -> {'psychology', 'medicine'}
# Beauty and the Beast objects -> {'factotum'}
# Beauty and the Beast woman -> {'factotum'}
# Beauty and the Beast returns -> {'tax', 'law'}
# Beauty and the Beast defeats -> {'factotum'}
# Beauty and the Beast basement -> {'buildings'}
# Beauty and the Beast village -> {'factotum'}
# Beauty and the Beast tower -> {'factotum'}
# Beauty and the Beast refuge -> {'factotum'}
# Beauty and the Beast search -> {'factotum'}
# Beauty and the Beast rescue -> {'factotum'}
# Beauty and the Beast arrest -> {'law'}
# Beauty and the Beast son -> {'person'}
# Beauty and the Beast departure -> {'factotum'}
# Beauty and the Beast uses -> {'factotum'}
# Beauty and the Beast appearance -> {'factotum'}
# Beauty and the Beast knife -> {'factotum'}
# Beauty and the Beast sharing -> {'biology'}
# Beauty and the Beast choice -> {'factotum'}
# Beauty and the Beast process -> {'factotum'}
# Beauty and the Beast monsieur -> {'factotum'}
# Beauty and the Beast asylum -> {'factotum'}
# Beauty and the Beast ventures -> {'factotum'}
# Beauty and the Beast help -> {'factotum'}
# Beauty and the Beast predicament -> {'factotum'}
# Beauty and the Beast belle -> {'factotum'}
# Beauty and the Beast metamorphoses -> {'biology', 'animals'}
# Beauty and the Beast spell -> {'psychology'}
# Beauty and the Beast showcase -> {'factotum'}
# Beauty and the Beast rallies -> {'factotum'}
# Beauty and the Beast stabs -> {'psychological_features'}
# Beauty and the Beast offers -> {'factotum'}
# Beauty and the Beast falls -> {'tourism', 'geography'}
# Beauty and the Beast seeing -> {'factotum'}
# Beauty and the Beast refuses -> {'factotum'}
# Beauty and the Beast girl -> {'factotum'}
# Beauty and the Beast book -> {'publishing'}
# Beauty and the Beast leaves -> {'plants'}
# Beauty and the Beast clock -> {'metrology'}
# Beauty and the Beast lack -> {'factotum'}
# Beauty and the Beast bribes -> {'economy'}
# Beauty and the Beast friendship -> {'factotum'}
# Beauty and the Beast footing -> {'sociology'}
# Beauty and the Beast hunter -> {'hunting'}
# Beauty and the Beast chopper -> {'factotum'}
# Beauty and the Beast loves -> {'psychological_features'}
# Beauty and the Beast invite -> {'post'}
# Beauty and the Beast arms -> {'military'}
# Beauty and the Beast nurses -> {'medicine'}
# Beauty and the Beast attacks -> {'factotum'}
# Beauty and the Beast mob -> {'factotum'}
# Beauty and the Beast wolves -> {'biology', 'animals'}
# Beauty and the Beast years -> {'time_period'}
# Beauty and the Beast take -> {'money'}
# Beauty and the Beast father -> {'person'}
# Beauty and the Beast finds -> {'factotum'}
# Beauty and the Beast fight -> {'factotum'}
# Beauty and the Beast brush -> {'plants', 'biology'}
# Beauty and the Beast spares -> {'factotum'}
# Beauty and the Beast rescues -> {'factotum'}
# Beauty and the Beast releases -> {'commerce'}
# Beauty and the Beast dreams -> {'physiology'}
# Beauty and the Beast hatches -> {'anatomy'}
# Beauty and the Beast rose -> {'plants', 'biology'}
# Beauty and the Beast battle -> {'history', 'military'}
# Beauty and the Beast way -> {'factotum'}
# Beauty and the Beast scares -> {'psychology'}
# Beauty and the Beast woods -> {'plants', 'biology'}
# Beauty and the Beast villagers -> {'geography'}
# Beauty and the Beast hearing -> {'law'}
# Beauty and the Beast outsider -> {'person'}
# Beauty and the Beast giving -> {'factotum'}
# Beauty and the Beast invention -> {'factotum'}
# Beauty and the Beast inventor -> {'person'}
# Beauty and the Beast life -> {'factotum'}
# Beauty and the Beast
# Counter({'factotum': 57,
#          'person': 8,
#          'biology': 8,
#          'plants': 6,
#          'psychological_features': 4,
#          'law': 4,
#          'medicine': 4,
#          'buildings': 3,
#          'geography': 3,
#          'military': 3,
#          'animals': 3,
#          'psychology': 3,
#          'money': 2,
#          'anatomy': 2,
#          'gastronomy': 2,
#          'time_period': 2,
#          'card': 1,
#          'administration': 1,
#          'politics': 1,
#          'computer_science': 1,
#          'town_planning': 1,
#          'entomology': 1,
#          'linguistics': 1,
#          'electrotechnology': 1,
#          'electronics': 1,
#          'finance': 1,
#          'art': 1,
#          'tax': 1,
#          'tourism': 1,
#          'publishing': 1,
#          'metrology': 1,
#          'economy': 1,
#          'sociology': 1,
#          'hunting': 1,
#          'post': 1,
#          'commerce': 1,
#          'physiology': 1,
#          'history': 1})
# A Bug's Life
# Counter()
# DuckTales the Movie: Treasure of the Lost Lamp return -> {'tax', 'law'}
# DuckTales the Movie: Treasure of the Lost Lamp trick -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp overrides -> {'mechanics'}
# DuckTales the Movie: Treasure of the Lost Lamp death -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp grant -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp escape -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp ball -> {'sport', 'play'}
# DuckTales the Movie: Treasure of the Lost Lamp yelling -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp forces -> {'military'}
# DuckTales the Movie: Treasure of the Lost Lamp mistakes -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp friend -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp animal -> {'biology', 'animals'}
# DuckTales the Movie: Treasure of the Lost Lamp trousers -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp baby -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp ice -> {'chemistry'}
# DuckTales the Movie: Treasure of the Lost Lamp play -> {'literature', 'theatre'}
# DuckTales the Movie: Treasure of the Lost Lamp packing -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp nephews -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp flying -> {'aviation'}
# DuckTales the Movie: Treasure of the Lost Lamp things -> {'economy'}
# DuckTales the Movie: Treasure of the Lost Lamp sees -> {'administration', 'law', 'town_planning'}
# DuckTales the Movie: Treasure of the Lost Lamp boy -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp lost -> {'medicine'}
# DuckTales the Movie: Treasure of the Lost Lamp room -> {'buildings'}
# DuckTales the Movie: Treasure of the Lost Lamp fortune -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp gravy -> {'gastronomy'}
# DuckTales the Movie: Treasure of the Lost Lamp identity -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp money -> {'money'}
# DuckTales the Movie: Treasure of the Lost Lamp takes -> {'money'}
# DuckTales the Movie: Treasure of the Lost Lamp friends -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp knock -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp children -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp value -> {'mathematics', 'number'}
# DuckTales the Movie: Treasure of the Lost Lamp fortress -> {'military'}
# DuckTales the Movie: Treasure of the Lost Lamp holds -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp wind -> {'meteorology'}
# DuckTales the Movie: Treasure of the Lost Lamp dust -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp forms -> {'linguistics'}
# DuckTales the Movie: Treasure of the Lost Lamp lamp -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp set -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp runs -> {'sport', 'play'}
# DuckTales the Movie: Treasure of the Lost Lamp must -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp earth -> {'astronomy'}
# DuckTales the Movie: Treasure of the Lost Lamp keep -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp grants -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp rules -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp wishes -> {'psychological_features'}
# DuckTales the Movie: Treasure of the Lost Lamp raises -> {'economy'}
# DuckTales the Movie: Treasure of the Lost Lamp edge -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp hand -> {'person', 'anatomy'}
# DuckTales the Movie: Treasure of the Lost Lamp group -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp hands -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp sundae -> {'gastronomy'}
# DuckTales the Movie: Treasure of the Lost Lamp boys -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp struggle -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp wishing -> {'psychological_features'}
# DuckTales the Movie: Treasure of the Lost Lamp pocket -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp pants -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp transport -> {'transport'}
# DuckTales the Movie: Treasure of the Lost Lamp flies -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp uses -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp family -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp use -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp grappling -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp spots -> {'medicine'}
# DuckTales the Movie: Treasure of the Lost Lamp drags -> {'physics', 'mechanics'}
# DuckTales the Movie: Treasure of the Lost Lamp dear -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp knocks -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp desires -> {'psychological_features'}
# DuckTales the Movie: Treasure of the Lost Lamp days -> {'time_period'}
# DuckTales the Movie: Treasure of the Lost Lamp society -> {'anthropology'}
# DuckTales the Movie: Treasure of the Lost Lamp help -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp impress -> {'law'}
# DuckTales the Movie: Treasure of the Lost Lamp cream -> {'sociology'}
# DuckTales the Movie: Treasure of the Lost Lamp evil -> {'sociology'}
# DuckTales the Movie: Treasure of the Lost Lamp woodchuck -> {'animals'}
# DuckTales the Movie: Treasure of the Lost Lamp sand -> {'geology'}
# DuckTales the Movie: Treasure of the Lost Lamp centuries -> {'time_period'}
# DuckTales the Movie: Treasure of the Lost Lamp works -> {'industry'}
# DuckTales the Movie: Treasure of the Lost Lamp destruction -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp falls -> {'tourism', 'geography'}
# DuckTales the Movie: Treasure of the Lost Lamp grip -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp night -> {'time_period'}
# DuckTales the Movie: Treasure of the Lost Lamp stuffing -> {'gastronomy'}
# DuckTales the Movie: Treasure of the Lost Lamp control -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp hanging -> {'architecture'}
# DuckTales the Movie: Treasure of the Lost Lamp scorpions -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp leaves -> {'plants'}
# DuckTales the Movie: Treasure of the Lost Lamp travels -> {'tourism'}
# DuckTales the Movie: Treasure of the Lost Lamp robe -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp lets -> {'politics'}
# DuckTales the Movie: Treasure of the Lost Lamp tells -> {'archery', 'history'}
# DuckTales the Movie: Treasure of the Lost Lamp poses -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp find -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp freedom -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp world -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp disloyalty -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp take -> {'money'}
# DuckTales the Movie: Treasure of the Lost Lamp air -> {'physics'}
# DuckTales the Movie: Treasure of the Lost Lamp stop -> {'transport'}
# DuckTales the Movie: Treasure of the Lost Lamp causing -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp chases -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp bird -> {'biology', 'animals'}
# DuckTales the Movie: Treasure of the Lost Lamp found -> {'economy'}
# DuckTales the Movie: Treasure of the Lost Lamp treasure -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp toys -> {'play'}
# DuckTales the Movie: Treasure of the Lost Lamp steal -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp boat -> {'nautical', 'tourism'}
# DuckTales the Movie: Treasure of the Lost Lamp power -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp vacation -> {'free_time', 'tourism'}
# DuckTales the Movie: Treasure of the Lost Lamp gene -> {'chemistry', 'biology'}
# DuckTales the Movie: Treasure of the Lost Lamp map -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp possession -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp launchpad -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp fall -> {'time_period'}
# DuckTales the Movie: Treasure of the Lost Lamp giving -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp scout -> {'person'}
# DuckTales the Movie: Treasure of the Lost Lamp life -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp says -> {'factotum'}
# DuckTales the Movie: Treasure of the Lost Lamp clothes -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp house -> {'town_planning', 'buildings'}
# DuckTales the Movie: Treasure of the Lost Lamp stole -> {'fashion'}
# DuckTales the Movie: Treasure of the Lost Lamp
# Counter({'factotum': 51,
#          'person': 8,
#          'fashion': 6,
#          'time_period': 4,
#          'tourism': 4,
#          'law': 3,
#          'play': 3,
#          'biology': 3,
#          'animals': 3,
#          'economy': 3,
#          'gastronomy': 3,
#          'money': 3,
#          'psychological_features': 3,
#          'mechanics': 2,
#          'sport': 2,
#          'military': 2,
#          'chemistry': 2,
#          'town_planning': 2,
#          'medicine': 2,
#          'buildings': 2,
#          'transport': 2,
#          'physics': 2,
#          'sociology': 2,
#          'tax': 1,
#          'literature': 1,
#          'theatre': 1,
#          'aviation': 1,
#          'administration': 1,
#          'mathematics': 1,
#          'number': 1,
#          'meteorology': 1,
#          'linguistics': 1,
#          'astronomy': 1,
#          'anatomy': 1,
#          'anthropology': 1,
#          'geology': 1,
#          'industry': 1,
#          'geography': 1,
#          'architecture': 1,
#          'plants': 1,
#          'politics': 1,
#          'archery': 1,
#          'history': 1,
#          'nautical': 1,
#          'free_time': 1})
# Aladdin saves -> {'sport'}
# Aladdin tricks -> {'factotum'}
# Aladdin bound -> {'factotum'}
# Aladdin return -> {'tax', 'law'}
# Aladdin truth -> {'factotum'}
# Aladdin wonders -> {'psychological_features'}
# Aladdin taking -> {'factotum'}
# Aladdin rush -> {'factotum'}
# Aladdin escapes -> {'factotum'}
# Aladdin means -> {'factotum'}
# Aladdin cave -> {'earth'}
# Aladdin capture -> {'factotum'}
# Aladdin escape -> {'factotum'}
# Aladdin help -> {'factotum'}
# Aladdin start -> {'factotum'}
# Aladdin man -> {'factotum'}
# Aladdin cost -> {'economy'}
# Aladdin plot -> {'factotum'}
# Aladdin servitude -> {'factotum'}
# Aladdin meets -> {'sport'}
# Aladdin gives -> {'physics'}
# Aladdin demand -> {'economy'}
# Aladdin ride -> {'tourism'}
# Aladdin frees -> {'factotum'}
# Aladdin throw -> {'factotum'}
# Aladdin diamond -> {'jewellery'}
# Aladdin orders -> {'factotum'}
# Aladdin peasant -> {'person'}
# Aladdin ordering -> {'factotum'}
# Aladdin lies -> {'factotum'}
# Aladdin plots -> {'factotum'}
# Aladdin lives -> {'factotum'}
# Aladdin wish -> {'psychological_features'}
# Aladdin refuses -> {'factotum'}
# Aladdin city -> {'administration', 'town_planning', 'geography'}
# Aladdin identity -> {'factotum'}
# Aladdin parrot -> {'biology', 'animals'}
# Aladdin stay -> {'tourism'}
# Aladdin throws -> {'factotum'}
# Aladdin takes -> {'money'}
# Aladdin ends -> {'factotum'}
# Aladdin promises -> {'factotum'}
# Aladdin host -> {'person'}
# Aladdin leaves -> {'plants'}
# Aladdin discusses -> {'sport'}
# Aladdin lamp -> {'factotum'}
# Aladdin loves -> {'psychological_features'}
# Aladdin sea -> {'geography'}
# Aladdin promise -> {'factotum'}
# Aladdin carpet -> {'furniture'}
# Aladdin rubs -> {'factotum'}
# Aladdin river -> {'tourism', 'geography'}
# Aladdin exiles -> {'law'}
# Aladdin rule -> {'factotum'}
# Aladdin dresses -> {'fashion'}
# Aladdin using -> {'factotum'}
# Aladdin jewel -> {'jewellery'}
# Aladdin breaks -> {'factotum'}
# Aladdin seek -> {'computer_science'}
# Aladdin world -> {'factotum'}
# Aladdin changes -> {'factotum'}
# Aladdin love -> {'psychological_features'}
# Aladdin monkey -> {'animals'}
# Aladdin sultan -> {'history'}
# Aladdin keep -> {'factotum'}
# Aladdin grants -> {'factotum'}
# Aladdin father -> {'person'}
# Aladdin notices -> {'factotum'}
# Aladdin finds -> {'factotum'}
# Aladdin suggestion -> {'factotum'}
# Aladdin steals -> {'factotum'}
# Aladdin wishes -> {'psychological_features'}
# Aladdin stresses -> {'art', 'linguistics'}
# Aladdin street -> {'town_planning', 'transport'}
# Aladdin collapses -> {'medicine'}
# Aladdin home -> {'factotum'}
# Aladdin title -> {'literature', 'administration'}
# Aladdin wasteland -> {'geography'}
# Aladdin touch -> {'factotum'}
# Aladdin returns -> {'tax', 'law'}
# Aladdin spotting -> {'factotum'}
# Aladdin freeing -> {'factotum'}
# Aladdin steal -> {'factotum'}
# Aladdin law -> {'law'}
# Aladdin vizier -> {'administration'}
# Aladdin taunts -> {'psychology'}
# Aladdin tries -> {'factotum'}
# Aladdin fate -> {'factotum'}
# Aladdin heroes -> {'history'}
# Aladdin guards -> {'person'}
# Aladdin uses -> {'factotum'}
# Aladdin jasmine -> {'plants', 'biology'}
# Aladdin says -> {'factotum'}
# Aladdin life -> {'factotum'}
# Aladdin person -> {'person', 'biology'}
# Aladdin use -> {'factotum'}
# Aladdin exposes -> {'factotum'}
# Aladdin release -> {'commerce'}
# Aladdin
# Counter({'factotum': 52,
#          'psychological_features': 5,
#          'person': 5,
#          'law': 4,
#          'geography': 4,
#          'sport': 3,
#          'tourism': 3,
#          'administration': 3,
#          'biology': 3,
#          'tax': 2,
#          'economy': 2,
#          'jewellery': 2,
#          'town_planning': 2,
#          'animals': 2,
#          'plants': 2,
#          'history': 2,
#          'earth': 1,
#          'physics': 1,
#          'money': 1,
#          'furniture': 1,
#          'fashion': 1,
#          'computer_science': 1,
#          'art': 1,
#          'linguistics': 1,
#          'transport': 1,
#          'medicine': 1,
#          'literature': 1,
#          'psychology': 1,
#          'commerce': 1})
# Tarzan leader -> {'person'}
# Tarzan return -> {'tax', 'law'}
# Tarzan go -> {'time_period'}
# Tarzan goodbye -> {'factotum'}
# Tarzan escapes -> {'factotum'}
# Tarzan following -> {'person'}
# Tarzan death -> {'factotum'}
# Tarzan capture -> {'factotum'}
# Tarzan camp -> {'military', 'buildings'}
# Tarzan escape -> {'factotum'}
# Tarzan respect -> {'factotum'}
# Tarzan opportunity -> {'factotum'}
# Tarzan grounds -> {'factotum'}
# Tarzan area -> {'geography'}
# Tarzan baby -> {'person'}
# Tarzan savage -> {'history', 'anthropology'}
# Tarzan makes -> {'factotum'}
# Tarzan porters -> {'tourism'}
# Tarzan humans -> {'factotum'}
# Tarzan band -> {'factotum'}
# Tarzan wish -> {'psychological_features'}
# Tarzan arrival -> {'factotum'}
# Tarzan fortune -> {'factotum'}
# Tarzan trees -> {'plants'}
# Tarzan takes -> {'money'}
# Tarzan turns -> {'transport'}
# Tarzan shotgun -> {'military'}
# Tarzan begin -> {'history', 'politics'}
# Tarzan place -> {'factotum'}
# Tarzan gorilla -> {'biology', 'animals'}
# Tarzan leave -> {'factotum'}
# Tarzan successor -> {'person'}
# Tarzan naming -> {'factotum'}
# Tarzan looking -> {'factotum'}
# Tarzan using -> {'factotum'}
# Tarzan teach -> {'law'}
# Tarzan branches -> {'administration'}
# Tarzan share -> {'exchange'}
# Tarzan cries -> {'factotum'}
# Tarzan suit -> {'law'}
# Tarzan differences -> {'factotum'}
# Tarzan plan -> {'factotum'}
# Tarzan team -> {'sport'}
# Tarzan killing -> {'factotum'}
# Tarzan spear -> {'military'}
# Tarzan kill -> {'sociology'}
# Tarzan group -> {'factotum'}
# Tarzan hands -> {'factotum'}
# Tarzan gadgets -> {'factotum'}
# Tarzan sell -> {'commerce'}
# Tarzan projector -> {'optics'}
# Tarzan slashes -> {'medicine'}
# Tarzan action -> {'factotum'}
# Tarzan objects -> {'factotum'}
# Tarzan century -> {'time_period'}
# Tarzan returns -> {'tax', 'law'}
# Tarzan vines -> {'plants'}
# Tarzan lead -> {'chemistry'}
# Tarzan tries -> {'factotum'}
# Tarzan efforts -> {'factotum'}
# Tarzan ship -> {'nautical', 'economy'}
# Tarzan months -> {'time_period'}
# Tarzan adult -> {'person'}
# Tarzan wreckage -> {'factotum'}
# Tarzan dying -> {'time_period'}
# Tarzan end -> {'factotum'}
# Tarzan family -> {'person'}
# Tarzan use -> {'factotum'}
# Tarzan tree -> {'plants'}
# Tarzan slide -> {'pure_science'}
# Tarzan elephant -> {'biology', 'animals'}
# Tarzan desires -> {'psychological_features'}
# Tarzan decision -> {'factotum'}
# Tarzan help -> {'factotum'}
# Tarzan advancement -> {'factotum'}
# Tarzan begins -> {'history', 'politics'}
# Tarzan civilization -> {'anthropology'}
# Tarzan tour -> {'tourism'}
# Tarzan baboon -> {'animals'}
# Tarzan views -> {'factotum'}
# Tarzan fights -> {'factotum'}
# Tarzan raise -> {'economy'}
# Tarzan locks -> {'vehicles', 'buildings'}
# Tarzan warnings -> {'factotum'}
# Tarzan lure -> {'factotum'}
# Tarzan refuses -> {'factotum'}
# Tarzan drifts -> {'physics'}
# Tarzan stay -> {'tourism'}
# Tarzan coast -> {'geology'}
# Tarzan traps -> {'factotum'}
# Tarzan hanging -> {'architecture'}
# Tarzan feelings -> {'psychological_features'}
# Tarzan garner -> {'commerce'}
# Tarzan poachers -> {'factotum'}
# Tarzan storage -> {'factotum'}
# Tarzan animals -> {'biology', 'animals'}
# Tarzan hunter -> {'hunting'}
# Tarzan gorillas -> {'biology', 'animals'}
# Tarzan study -> {'factotum'}
# Tarzan find -> {'factotum'}
# Tarzan jumps -> {'factotum'}
# Tarzan attacks -> {'factotum'}
# Tarzan explorers -> {'history'}
# Tarzan aged -> {'factotum'}
# Tarzan leads -> {'chemistry'}
# Tarzan vine -> {'plants'}
# Tarzan finds -> {'factotum'}
# Tarzan mate -> {'nautical', 'person'}
# Tarzan causing -> {'factotum'}
# Tarzan spares -> {'factotum'}
# Tarzan daughter -> {'person'}
# Tarzan professor -> {'school', 'university'}
# Tarzan couple -> {'factotum'}
# Tarzan treetops -> {'factotum'}
# Tarzan interest -> {'psychology'}
# Tarzan battle -> {'history', 'military'}
# Tarzan names -> {'factotum'}
# Tarzan found -> {'economy'}
# Tarzan troop -> {'military'}
# Tarzan build -> {'factotum'}
# Tarzan encounters -> {'factotum'}
# Tarzan meet -> {'sport'}
# Tarzan remains -> {'factotum'}
# Tarzan possession -> {'factotum'}
# Tarzan fall -> {'time_period'}
# Tarzan day -> {'factotum'}
# Tarzan boards -> {'skating', 'hockey', 'buildings'}
# Tarzan life -> {'factotum'}
# Tarzan says -> {'factotum'}
# Tarzan stops -> {'card'}
# Tarzan shoots -> {'plants'}
# Tarzan
# Counter({'factotum': 61,
#          'person': 8,
#          'time_period': 5,
#          'military': 5,
#          'history': 5,
#          'plants': 5,
#          'animals': 5,
#          'law': 4,
#          'biology': 4,
#          'buildings': 3,
#          'tourism': 3,
#          'psychological_features': 3,
#          'economy': 3,
#          'tax': 2,
#          'anthropology': 2,
#          'politics': 2,
#          'sport': 2,
#          'commerce': 2,
#          'chemistry': 2,
#          'nautical': 2,
#          'geography': 1,
#          'money': 1,
#          'transport': 1,
#          'administration': 1,
#          'exchange': 1,
#          'sociology': 1,
#          'optics': 1,
#          'medicine': 1,
#          'pure_science': 1,
#          'vehicles': 1,
#          'physics': 1,
#          'geology': 1,
#          'architecture': 1,
#          'hunting': 1,
#          'school': 1,
#          'university': 1,
#          'psychology': 1,
#          'skating': 1,
#          'hockey': 1,
#          'card': 1})
# Mulan leader -> {'person'}
# Mulan return -> {'tax', 'law'}
# Mulan rocket -> {'transport'}
# Mulan launching -> {'factotum'}
# Mulan resolves -> {'psychological_features'}
# Mulan encampment -> {'tourism'}
# Mulan capture -> {'factotum'}
# Mulan camp -> {'military', 'buildings'}
# Mulan sword -> {'military'}
# Mulan cause -> {'factotum'}
# Mulan dies -> {'card'}
# Mulan warriors -> {'military'}
# Mulan survival -> {'factotum'}
# Mulan safety -> {'factotum'}
# Mulan strikes -> {'sociology'}
# Mulan declines -> {'factotum'}
# Mulan sight -> {'factotum'}
# Mulan offer -> {'factotum'}
# Mulan bow -> {'factotum'}
# Mulan pass -> {'baseball'}
# Mulan celebration -> {'sociology'}
# Mulan acting -> {'theatre'}
# Mulan honor -> {'factotum'}
# Mulan leave -> {'factotum'}
# Mulan dinner -> {'gastronomy'}
# Mulan pose -> {'factotum'}
# Mulan set -> {'factotum'}
# Mulan emperor -> {'history', 'person'}
# Mulan war -> {'history', 'military'}
# Mulan notices -> {'factotum'}
# Mulan gifts -> {'factotum'}
# Mulan make -> {'factotum'}
# Mulan led -> {'electrotechnology', 'electronics'}
# Mulan guidance -> {'factotum'}
# Mulan slashes -> {'medicine'}
# Mulan grandmother -> {'factotum'}
# Mulan returns -> {'tax', 'law'}
# Mulan fellow -> {'factotum'}
# Mulan tower -> {'factotum'}
# Mulan ancestors -> {'factotum'}
# Mulan law -> {'law'}
# Mulan shang -> {'factotum'}
# Mulan captain -> {'military'}
# Mulan departure -> {'factotum'}
# Mulan executing -> {'law'}
# Mulan uses -> {'factotum'}
# Mulan family -> {'person'}
# Mulan taking -> {'factotum'}
# Mulan hair -> {'anatomy'}
# Mulan invitation -> {'post'}
# Mulan instructions -> {'publishing'}
# Mulan concubines -> {'factotum'}
# Mulan process -> {'factotum'}
# Mulan palace -> {'buildings'}
# Mulan order -> {'factotum'}
# Mulan veteran -> {'military'}
# Mulan health -> {'medicine'}
# Mulan training -> {'factotum'}
# Mulan disguises -> {'factotum'}
# Mulan cannon -> {'military'}
# Mulan ling -> {'plants'}
# Mulan inhabitants -> {'geography'}
# Mulan help -> {'factotum'}
# Mulan recruits -> {'military'}
# Mulan reporting -> {'factotum'}
# Mulan man -> {'factotum'}
# Mulan defeat -> {'factotum'}
# Mulan invaders -> {'person'}
# Mulan deception -> {'factotum'}
# Mulan cutting -> {'cinema'}
# Mulan roof -> {'buildings'}
# Mulan report -> {'factotum'}
# Mulan destruction -> {'factotum'}
# Mulan orders -> {'factotum'}
# Mulan see -> {'administration', 'law', 'town_planning'}
# Mulan fires -> {'factotum'}
# Mulan views -> {'factotum'}
# Mulan ordering -> {'factotum'}
# Mulan mountains -> {'geology', 'geography'}
# Mulan going -> {'factotum'}
# Mulan city -> {'administration', 'town_planning', 'geography'}
# Mulan stay -> {'tourism'}
# Mulan wound -> {'medicine'}
# Mulan skyrocket -> {'factotum'}
# Mulan join -> {'factotum'}
# Mulan combat -> {'history', 'military'}
# Mulan reinforcements -> {'factotum'}
# Mulan dragon -> {'mythology'}
# Mulan troops -> {'military'}
# Mulan catches -> {'factotum'}
# Mulan skills -> {'factotum'}
# Mulan father -> {'person'}
# Mulan spares -> {'factotum'}
# Mulan home -> {'factotum'}
# Mulan explosion -> {'military'}
# Mulan way -> {'factotum'}
# Mulan men -> {'economy'}
# Mulan intent -> {'factotum'}
# Mulan news -> {'factotum'}
# Mulan presents -> {'time_period'}
# Mulan huns -> {'history'}
# Mulan left -> {'factotum'}
# Mulan life -> {'factotum'}
# Mulan parent -> {'person'}
# Mulan mobilization -> {'military'}
# Mulan
# Counter({'factotum': 54,
#          'military': 12,
#          'person': 6,
#          'law': 5,
#          'history': 4,
#          'buildings': 3,
#          'medicine': 3,
#          'geography': 3,
#          'tax': 2,
#          'tourism': 2,
#          'sociology': 2,
#          'administration': 2,
#          'town_planning': 2,
#          'transport': 1,
#          'psychological_features': 1,
#          'card': 1,
#          'baseball': 1,
#          'theatre': 1,
#          'gastronomy': 1,
#          'electrotechnology': 1,
#          'electronics': 1,
#          'anatomy': 1,
#          'post': 1,
#          'publishing': 1,
#          'plants': 1,
#          'cinema': 1,
#          'geology': 1,
#          'mythology': 1,
#          'economy': 1,
#          'time_period': 1})
# A Goofy Movie saves -> {'sport'}
# A Goofy Movie go -> {'time_period'}
# A Goofy Movie return -> {'tax', 'law'}
# A Goofy Movie truth -> {'factotum'}
# A Goofy Movie following -> {'person'}
# A Goofy Movie story -> {'factotum'}
# A Goofy Movie camp -> {'military', 'buildings'}
# A Goofy Movie deaths -> {'factotum'}
# A Goofy Movie conversation -> {'factotum'}
# A Goofy Movie dance -> {'dance'}
# A Goofy Movie drives -> {'factotum'}
# A Goofy Movie town -> {'town_planning', 'geography'}
# A Goofy Movie date -> {'factotum'}
# A Goofy Movie results -> {'factotum'}
# A Goofy Movie cross -> {'factotum'}
# A Goofy Movie takes -> {'money'}
# A Goofy Movie friends -> {'person'}
# A Goofy Movie telling -> {'literature'}
# A Goofy Movie learning -> {'psychoanalysis', 'pedagogy'}
# A Goofy Movie place -> {'factotum'}
# A Goofy Movie stage -> {'time_period', 'biology'}
# A Goofy Movie country -> {'geography'}
# A Goofy Movie leave -> {'factotum'}
# A Goofy Movie hijack -> {'law'}
# A Goofy Movie making -> {'fashion'}
# A Goofy Movie proceeds -> {'money'}
# A Goofy Movie opossum -> {'biology', 'animals'}
# A Goofy Movie river -> {'tourism', 'geography'}
# A Goofy Movie using -> {'factotum'}
# A Goofy Movie love -> {'psychological_features'}
# A Goofy Movie celebrity -> {'person'}
# A Goofy Movie destiny -> {'factotum'}
# A Goofy Movie keep -> {'factotum'}
# A Goofy Movie behavior -> {'psychology'}
# A Goofy Movie punishment -> {'law'}
# A Goofy Movie sleeps -> {'physiology'}
# A Goofy Movie objections -> {'factotum'}
# A Goofy Movie waterfall -> {'tourism', 'geography'}
# A Goofy Movie make -> {'factotum'}
# A Goofy Movie car -> {'transport', 'tourism'}
# A Goofy Movie boys -> {'factotum'}
# A Goofy Movie may -> {'metrology', 'time_period'}
# A Goofy Movie capital -> {'factotum'}
# A Goofy Movie morning -> {'time_period'}
# A Goofy Movie televisions -> {'telecommunication'}
# A Goofy Movie leaving -> {'factotum'}
# A Goofy Movie argument -> {'telecommunication'}
# A Goofy Movie concert -> {'telecommunication', 'theatre', 'racing', 'sociology'}
# A Goofy Movie end -> {'factotum'}
# A Goofy Movie son -> {'person'}
# A Goofy Movie mentions -> {'factotum'}
# A Goofy Movie peers -> {'history', 'person'}
# A Goofy Movie waiting -> {'factotum'}
# A Goofy Movie taking -> {'factotum'}
# A Goofy Movie process -> {'factotum'}
# A Goofy Movie brake -> {'transport'}
# A Goofy Movie theme -> {'factotum'}
# A Goofy Movie porch -> {'buildings'}
# A Goofy Movie plans -> {'factotum'}
# A Goofy Movie leading -> {'publishing'}
# A Goofy Movie panics -> {'psychological_features'}
# A Goofy Movie chase -> {'factotum'}
# A Goofy Movie performance -> {'telecommunication', 'theatre', 'racing', 'sociology'}
# A Goofy Movie motel -> {'town_planning', 'tourism', 'buildings'}
# A Goofy Movie roof -> {'buildings'}
# A Goofy Movie pop -> {'person'}
# A Goofy Movie result -> {'factotum'}
# A Goofy Movie calls -> {'telephony'}
# A Goofy Movie sent -> {'money', 'metrology'}
# A Goofy Movie shows -> {'free_time'}
# A Goofy Movie seeing -> {'factotum'}
# A Goofy Movie starts -> {'factotum'}
# A Goofy Movie falls -> {'tourism', 'geography'}
# A Goofy Movie going -> {'factotum'}
# A Goofy Movie locations -> {'factotum'}
# A Goofy Movie speech -> {'factotum'}
# A Goofy Movie control -> {'factotum'}
# A Goofy Movie technique -> {'factotum'}
# A Goofy Movie night -> {'time_period'}
# A Goofy Movie camping -> {'tourism'}
# A Goofy Movie feelings -> {'psychological_features'}
# A Goofy Movie hurts -> {'medicine'}
# A Goofy Movie auditorium -> {'town_planning'}
# A Goofy Movie television -> {'telecommunication'}
# A Goofy Movie promise -> {'factotum'}
# A Goofy Movie tells -> {'archery', 'history'}
# A Goofy Movie party -> {'history', 'sociology', 'politics', 'anthropology'}
# A Goofy Movie cast -> {'art'}
# A Goofy Movie storm -> {'meteorology'}
# A Goofy Movie fishing -> {'fishing'}
# A Goofy Movie traveling -> {'tourism'}
# A Goofy Movie canyon -> {'geology', 'geography'}
# A Goofy Movie years -> {'time_period'}
# A Goofy Movie take -> {'money'}
# A Goofy Movie father -> {'person'}
# A Goofy Movie stop -> {'transport'}
# A Goofy Movie home -> {'factotum'}
# A Goofy Movie facing -> {'fashion'}
# A Goofy Movie interest -> {'psychology'}
# A Goofy Movie relationship -> {'factotum'}
# A Goofy Movie damage -> {'factotum'}
# A Goofy Movie call -> {'telephony'}
# A Goofy Movie trip -> {'tourism'}
# A Goofy Movie meet -> {'sport'}
# A Goofy Movie vacation -> {'free_time', 'tourism'}
# A Goofy Movie singer -> {'music'}
# A Goofy Movie map -> {'factotum'}
# A Goofy Movie day -> {'factotum'}
# A Goofy Movie summer -> {'time_period'}
# A Goofy Movie anger -> {'psychological_features'}
# A Goofy Movie school -> {'school'}
# A Goofy Movie junction -> {'transport'}
# A Goofy Movie navigator -> {'nautical', 'person'}
# A Goofy Movie
# Counter({'factotum': 40,
#          'tourism': 9,
#          'person': 8,
#          'time_period': 7,
#          'geography': 6,
#          'telecommunication': 5,
#          'buildings': 4,
#          'money': 4,
#          'psychological_features': 4,
#          'transport': 4,
#          'law': 3,
#          'town_planning': 3,
#          'sociology': 3,
#          'history': 3,
#          'sport': 2,
#          'biology': 2,
#          'fashion': 2,
#          'psychology': 2,
#          'metrology': 2,
#          'theatre': 2,
#          'racing': 2,
#          'telephony': 2,
#          'free_time': 2,
#          'tax': 1,
#          'military': 1,
#          'dance': 1,
#          'literature': 1,
#          'psychoanalysis': 1,
#          'pedagogy': 1,
#          'animals': 1,
#          'physiology': 1,
#          'publishing': 1,
#          'medicine': 1,
#          'archery': 1,
#          'politics': 1,
#          'anthropology': 1,
#          'art': 1,
#          'meteorology': 1,
#          'fishing': 1,
#          'geology': 1,
#          'music': 1,
#          'school': 1,
#          'nautical': 1})
# Toy Story 2 planet -> {'astronomy'}
# Toy Story 2 bound -> {'factotum'}
# Toy Story 2 return -> {'tax', 'law'}
# Toy Story 2 carrier -> {'person'}
# Toy Story 2 go -> {'time_period'}
# Toy Story 2 aliens -> {'person'}
# Toy Story 2 escapes -> {'factotum'}
# Toy Story 2 utility -> {'factotum'}
# Toy Story 2 baggage -> {'factotum'}
# Toy Story 2 camp -> {'military', 'buildings'}
# Toy Story 2 escape -> {'factotum'}
# Toy Story 2 box -> {'factotum'}
# Toy Story 2 doll -> {'play'}
# Toy Story 2 delivery -> {'commerce'}
# Toy Story 2 people -> {'person'}
# Toy Story 2 ire -> {'psychological_features'}
# Toy Story 2 play -> {'literature', 'theatre'}
# Toy Story 2 mission -> {'religion'}
# Toy Story 2 handling -> {'factotum'}
# Toy Story 2 arm -> {'person', 'anatomy'}
# Toy Story 2 triggers -> {'buildings'}
# Toy Story 2 mix -> {'gastronomy'}
# Toy Story 2 boy -> {'factotum'}
# Toy Story 2 takes -> {'money'}
# Toy Story 2 turns -> {'transport'}
# Toy Story 2 children -> {'person'}
# Toy Story 2 waking -> {'psychology'}
# Toy Story 2 repairs -> {'factotum'}
# Toy Story 2 set -> {'factotum'}
# Toy Story 2 puts -> {'exchange', 'commerce'}
# Toy Story 2 squeaker -> {'factotum'}
# Toy Story 2 revealing -> {'factotum'}
# Toy Story 2 planning -> {'factotum'}
# Toy Story 2 prospector -> {'industry'}
# Toy Story 2 believing -> {'factotum'}
# Toy Story 2 blames -> {'law'}
# Toy Story 2 emperor -> {'history', 'person'}
# Toy Story 2 gang -> {'law'}
# Toy Story 2 sale -> {'commerce'}
# Toy Story 2 plane -> {'transport'}
# Toy Story 2 rogue -> {'person'}
# Toy Story 2 plan -> {'factotum'}
# Toy Story 2 shelf -> {'furniture', 'commerce'}
# Toy Story 2 turning -> {'transport'}
# Toy Story 2 fixes -> {'factotum'}
# Toy Story 2 wants -> {'finance'}
# Toy Story 2 morning -> {'time_period'}
# Toy Story 2 goes -> {'time_period'}
# Toy Story 2 action -> {'factotum'}
# Toy Story 2 returns -> {'tax', 'law'}
# Toy Story 2 apartment -> {'town_planning', 'buildings'}
# Toy Story 2 ranger -> {'administration', 'law'}
# Toy Story 2 rescue -> {'factotum'}
# Toy Story 2 months -> {'time_period'}
# Toy Story 2 success -> {'factotum'}
# Toy Story 2 character -> {'literature'}
# Toy Story 2 roundup -> {'enterprise', 'animal_husbandry'}
# Toy Story 2 tears -> {'physiology'}
# Toy Story 2 use -> {'factotum'}
# Toy Story 2 yard -> {'metrology'}
# Toy Story 2 process -> {'factotum'}
# Toy Story 2 truck -> {'transport'}
# Toy Story 2 dog -> {'biology', 'animals'}
# Toy Story 2 suitcase -> {'factotum'}
# Toy Story 2 knocks -> {'factotum'}
# Toy Story 2 museum -> {'town_planning', 'tourism'}
# Toy Story 2 sneak -> {'person'}
# Toy Story 2 belt -> {'factotum'}
# Toy Story 2 delight -> {'psychological_features'}
# Toy Story 2 system -> {'factotum'}
# Toy Story 2 joins -> {'factotum'}
# Toy Story 2 given -> {'factotum'}
# Toy Story 2 sleeping -> {'physiology'}
# Toy Story 2 frees -> {'factotum'}
# Toy Story 2 tour -> {'tourism'}
# Toy Story 2 calls -> {'telephony'}
# Toy Story 2 seeing -> {'factotum'}
# Toy Story 2 refuses -> {'factotum'}
# Toy Story 2 company -> {'enterprise'}
# Toy Story 2 attention -> {'factotum'}
# Toy Story 2 girl -> {'factotum'}
# Toy Story 2 stay -> {'tourism'}
# Toy Story 2 night -> {'time_period'}
# Toy Story 2 ends -> {'factotum'}
# Toy Story 2 leaves -> {'plants'}
# Toy Story 2 need -> {'factotum'}
# Toy Story 2 television -> {'telecommunication'}
# Toy Story 2 tells -> {'archery', 'history'}
# Toy Story 2 find -> {'factotum'}
# Toy Story 2 purpose -> {'factotum'}
# Toy Story 2 toy -> {'play'}
# Toy Story 2 battles -> {'history', 'military'}
# Toy Story 2 show -> {'free_time'}
# Toy Story 2 rips -> {'person'}
# Toy Story 2 finds -> {'factotum'}
# Toy Story 2 elevator -> {'town_planning', 'buildings'}
# Toy Story 2 space -> {'factotum'}
# Toy Story 2 pickaxe -> {'factotum'}
# Toy Story 2 rescues -> {'factotum'}
# Toy Story 2 collector -> {'free_time'}
# Toy Story 2 home -> {'factotum'}
# Toy Story 2 playing -> {'music'}
# Toy Story 2 head -> {'anatomy', 'animals'}
# Toy Story 2 mother -> {'person'}
# Toy Story 2 steal -> {'factotum'}
# Toy Story 2 toys -> {'play'}
# Toy Story 2 attempts -> {'factotum'}
# Toy Story 2 fate -> {'factotum'}
# Toy Story 2 reach -> {'mathematics'}
# Toy Story 2 experience -> {'pedagogy'}
# Toy Story 2 hearing -> {'law'}
# Toy Story 2 try -> {'factotum'}
# Toy Story 2 tv -> {'telecommunication'}
# Toy Story 2 collection -> {'factotum'}
# Toy Story 2 fix -> {'factotum'}
# Toy Story 2 shifting -> {'factotum'}
# Toy Story 2 airport -> {'town_planning', 'transport'}
# Toy Story 2 pizza -> {'gastronomy'}
# Toy Story 2 figure -> {'publishing'}
# Toy Story 2
# Counter({'factotum': 48,
#          'person': 10,
#          'law': 6,
#          'time_period': 5,
#          'transport': 5,
#          'buildings': 4,
#          'commerce': 4,
#          'town_planning': 4,
#          'play': 3,
#          'history': 3,
#          'tourism': 3,
#          'tax': 2,
#          'military': 2,
#          'psychological_features': 2,
#          'literature': 2,
#          'anatomy': 2,
#          'gastronomy': 2,
#          'enterprise': 2,
#          'physiology': 2,
#          'animals': 2,
#          'telecommunication': 2,
#          'free_time': 2,
#          'astronomy': 1,
#          'theatre': 1,
#          'religion': 1,
#          'money': 1,
#          'psychology': 1,
#          'exchange': 1,
#          'industry': 1,
#          'furniture': 1,
#          'finance': 1,
#          'administration': 1,
#          'animal_husbandry': 1,
#          'metrology': 1,
#          'biology': 1,
#          'telephony': 1,
#          'plants': 1,
#          'archery': 1,
#          'music': 1,
#          'mathematics': 1,
#          'pedagogy': 1,
#          'publishing': 1})
# Toy Story leader -> {'person'}
# Toy Story planet -> {'astronomy'}
# Toy Story saves -> {'sport'}
# Toy Story rocket -> {'transport'}
# Toy Story surprise -> {'psychological_features'}
# Toy Story feel -> {'factotum'}
# Toy Story impresses -> {'law'}
# Toy Story escapes -> {'factotum'}
# Toy Story glides -> {'linguistics'}
# Toy Story failing -> {'factotum'}
# Toy Story following -> {'person'}
# Toy Story confidence -> {'psychology'}
# Toy Story escape -> {'factotum'}
# Toy Story box -> {'factotum'}
# Toy Story doll -> {'play'}
# Toy Story spy -> {'person'}
# Toy Story smile -> {'factotum'}
# Toy Story delivery -> {'commerce'}
# Toy Story safety -> {'factotum'}
# Toy Story gives -> {'physics'}
# Toy Story drives -> {'factotum'}
# Toy Story mission -> {'religion'}
# Toy Story arm -> {'person', 'anatomy'}
# Toy Story favor -> {'factotum'}
# Toy Story soar -> {'factotum'}
# Toy Story makes -> {'factotum'}
# Toy Story things -> {'economy'}
# Toy Story boy -> {'factotum'}
# Toy Story takes -> {'money'}
# Toy Story piggy -> {'biology', 'animals'}
# Toy Story telling -> {'literature'}
# Toy Story army -> {'military'}
# Toy Story surgery -> {'medicine'}
# Toy Story toss -> {'betting'}
# Toy Story alien -> {'person'}
# Toy Story ease -> {'factotum'}
# Toy Story gas -> {'chemistry'}
# Toy Story run -> {'sport', 'play'}
# Toy Story share -> {'exchange'}
# Toy Story believing -> {'factotum'}
# Toy Story launch -> {'nautical'}
# Toy Story batteries -> {'military'}
# Toy Story gesture -> {'factotum'}
# Toy Story breaking -> {'industry'}
# Toy Story fear -> {'psychological_features'}
# Toy Story killing -> {'factotum'}
# Toy Story steals -> {'factotum'}
# Toy Story move -> {'factotum'}
# Toy Story make -> {'factotum'}
# Toy Story group -> {'factotum'}
# Toy Story led -> {'electrotechnology', 'electronics'}
# Toy Story car -> {'transport', 'tourism'}
# Toy Story situation -> {'factotum'}
# Toy Story bids -> {'factotum'}
# Toy Story morning -> {'time_period'}
# Toy Story action -> {'factotum'}
# Toy Story reaches -> {'mathematics'}
# Toy Story ranger -> {'administration', 'law'}
# Toy Story rescue -> {'factotum'}
# Toy Story argument -> {'telecommunication'}
# Toy Story joy -> {'psychological_features'}
# Toy Story potato -> {'chemistry', 'gastronomy'}
# Toy Story end -> {'factotum'}
# Toy Story sister -> {'person'}
# Toy Story family -> {'person'}
# Toy Story thinking -> {'factotum'}
# Toy Story duo -> {'number'}
# Toy Story arrivals -> {'factotum'}
# Toy Story week -> {'time_period'}
# Toy Story process -> {'factotum'}
# Toy Story truck -> {'transport'}
# Toy Story dog -> {'biology', 'animals'}
# Toy Story monitors -> {'electrotechnology', 'electronics', 'computer_science'}
# Toy Story days -> {'time_period'}
# Toy Story game -> {'sport'}
# Toy Story dinosaur -> {'animals'}
# Toy Story pretend -> {'sociology'}
# Toy Story help -> {'factotum'}
# Toy Story delight -> {'psychological_features'}
# Toy Story begins -> {'history', 'politics'}
# Toy Story fly -> {'entomology', 'biology'}
# Toy Story might -> {'quality'}
# Toy Story report -> {'factotum'}
# Toy Story ride -> {'tourism'}
# Toy Story knocking -> {'factotum'}
# Toy Story farewell -> {'factotum'}
# Toy Story neighbor -> {'person'}
# Toy Story window -> {'buildings'}
# Toy Story throws -> {'factotum'}
# Toy Story ends -> {'factotum'}
# Toy Story thinks -> {'factotum'}
# Toy Story television -> {'telecommunication'}
# ...
# Brave mistakes -> {'factotum'}
# Brave warriors -> {'military'}
# Brave gives -> {'physics'}
# Brave bargains -> {'factotum'}
# Brave room -> {'buildings'}
# Brave failure -> {'factotum'}
# Brave demands -> {'economy'}
# Brave ruins -> {'factotum'}
# Brave cake -> {'factotum'}
# Brave change -> {'factotum'}
# Brave refusal -> {'factotum'}
# Brave suitor -> {'person'}
# Brave allies -> {'factotum'}
# Brave castle -> {'buildings'}
# Brave horses -> {'biology', 'animals'}
# Brave repairs -> {'factotum'}
# Brave alliance -> {'enterprise'}
# Brave cubs -> {'person'}
# Brave runs -> {'sport', 'play'}
# Brave chieftains -> {'person'}
# Brave locking -> {'factotum'}
# Brave war -> {'history', 'military'}
# Brave breaking -> {'industry'}
# Brave wishes -> {'psychological_features'}
# Brave rules -> {'factotum'}
# Brave hand -> {'person', 'anatomy'}
# Brave vows -> {'factotum'}
# Brave witch -> {'occultism'}
# Brave led -> {'electrotechnology', 'electronics'}
# Brave meaning -> {'factotum'}
# Brave returns -> {'tax', 'law'}
# Brave humanity -> {'factotum'}
# Brave tradition -> {'factotum'}
# Brave argument -> {'telecommunication'}
# Brave son -> {'person'}
# Brave batters -> {'baseball', 'play'}
# Brave sister -> {'person'}
# Brave family -> {'person'}
# Brave encounter -> {'factotum'}
# Brave kingdom -> {'factotum'}
# Brave spirit -> {'religion'}
# Brave thanks -> {'factotum'}
# Brave thing -> {'factotum'}
# Brave mistaking -> {'factotum'}
# Brave games -> {'sport'}
# Brave holding -> {'factotum'}
# Brave bests -> {'factotum'}
# Brave contest -> {'sport'}
# Brave leading -> {'publishing'}
# Brave consciousness -> {'psychology'}
# Brave dismay -> {'psychological_features'}
# Brave effects -> {'economy'}
# Brave assistance -> {'factotum'}
# Brave betrothed -> {'person'}
# Brave clan -> {'factotum'}
# Brave given -> {'factotum'}
# Brave spell -> {'psychology'}
# Brave ride -> {'tourism'}
# Brave farewell -> {'factotum'}
# Brave prompts -> {'literature'}
# Brave twists -> {'factotum'}
# Brave marriage -> {'law', 'sociology'}
# Brave repair -> {'factotum'}
# Brave demon -> {'factotum'}
# Brave bid -> {'factotum'}
# Brave sunrise -> {'time_period'}
# Brave targets -> {'factotum'}
# Brave needs -> {'factotum'}
# Brave docks -> {'law'}
# Brave find -> {'factotum'}
# Brave attacks -> {'factotum'}
# Brave time -> {'factotum'}
# Brave legs -> {'quality'}
# Brave years -> {'time_period'}
# Brave causing -> {'factotum'}
# Brave cottage -> {'tourism', 'buildings'}
# Brave born -> {'physics'}
# Brave sons -> {'person'}
# Brave rises -> {'factotum'}
# Brave bond -> {'physics', 'chemistry'}
# Brave releases -> {'commerce'}
# Brave birthday -> {'time_period'}
# Brave mother -> {'person'}
# Brave costs -> {'economy'}
# Brave harm -> {'medicine'}
# Brave horseback -> {'anatomy', 'animals'}
# Brave encounters -> {'factotum'}
# Brave freeing -> {'factotum'}
# Brave men -> {'economy'}
# Brave woods -> {'plants', 'biology'}
# Brave fate -> {'factotum'}
# Brave message -> {'telecommunication'}
# Brave remains -> {'factotum'}
# Brave suitors -> {'person'}
# Brave tapestry -> {'factotum'}
# Brave stops -> {'card'}
# Brave
# Counter({'factotum': 47,
#          'person': 12,
#          'law': 4,
#          'economy': 4,
#          'tourism': 3,
#          'psychological_features': 3,
#          'physics': 3,
#          'buildings': 3,
#          'sport': 3,
#          'time_period': 3,
#          'tax': 2,
#          'military': 2,
#          'biology': 2,
#          'animals': 2,
#          'play': 2,
#          'anatomy': 2,
#          'telecommunication': 2,
#          'psychology': 2,
#          'artisanship': 1,
#          'geology': 1,
#          'geography': 1,
#          'politics': 1,
#          'enterprise': 1,
#          'history': 1,
#          'industry': 1,
#          'occultism': 1,
#          'electrotechnology': 1,
#          'electronics': 1,
#          'baseball': 1,
#          'religion': 1,
#          'publishing': 1,
#          'literature': 1,
#          'sociology': 1,
#          'quality': 1,
#          'chemistry': 1,
#          'commerce': 1,
#          'medicine': 1,
#          'plants': 1,
#          'card': 1})
# Winnie the Pooh visit -> {'factotum'}
# Winnie the Pooh scene -> {'factotum'}
# Winnie the Pooh return -> {'tax', 'law'}
# Winnie the Pooh items -> {'factotum'}
# Winnie the Pooh mud -> {'geology'}
# Winnie the Pooh instructions -> {'publishing'}
# Winnie the Pooh letters -> {'factotum'}
# Winnie the Pooh thing -> {'factotum'}
# Winnie the Pooh escapes -> {'factotum'}
# Winnie the Pooh following -> {'person'}
# Winnie the Pooh scarf -> {'fashion'}
# Winnie the Pooh plans -> {'factotum'}
# Winnie the Pooh knocks -> {'factotum'}
# Winnie the Pooh contest -> {'sport'}
# Winnie the Pooh leading -> {'publishing'}
# Winnie the Pooh escape -> {'factotum'}
# Winnie the Pooh dismay -> {'psychological_features'}
# Winnie the Pooh help -> {'factotum'}
# Winnie the Pooh recruits -> {'military'}
# Winnie the Pooh prize -> {'factotum'}
# Winnie the Pooh chase -> {'factotum'}
# Winnie the Pooh defeat -> {'factotum'}
# Winnie the Pooh mistakes -> {'factotum'}
# Winnie the Pooh hold -> {'factotum'}
# Winnie the Pooh given -> {'factotum'}
# Winnie the Pooh pot -> {'gastronomy'}
# Winnie the Pooh visits -> {'factotum'}
# Winnie the Pooh sidekick -> {'person'}
# Winnie the Pooh calls -> {'telephony'}
# Winnie the Pooh see -> {'administration', 'law', 'town_planning'}
# Winnie the Pooh think -> {'factotum'}
# Winnie the Pooh starts -> {'factotum'}
# Winnie the Pooh lost -> {'medicine'}
# Winnie the Pooh pit -> {'geology'}
# Winnie the Pooh monster -> {'factotum'}
# Winnie the Pooh pull -> {'factotum'}
# Winnie the Pooh read -> {'publishing'}
# Winnie the Pooh friends -> {'person'}
# Winnie the Pooh credits -> {'racing', 'sociology'}
# Winnie the Pooh bouncing -> {'factotum'}
# Winnie the Pooh ends -> {'factotum'}
# Winnie the Pooh tail -> {'anatomy', 'animals'}
# Winnie the Pooh leave -> {'factotum'}
# Winnie the Pooh note -> {'post'}
# Winnie the Pooh honey -> {'gastronomy'}
# Winnie the Pooh post -> {'factotum'}
# Winnie the Pooh find -> {'factotum'}
# Winnie the Pooh looking -> {'factotum'}
# Winnie the Pooh saying -> {'linguistics'}
# Winnie the Pooh form -> {'linguistics'}
# Winnie the Pooh dresses -> {'fashion'}
# Winnie the Pooh using -> {'factotum'}
# Winnie the Pooh teach -> {'law'}
# Winnie the Pooh runs -> {'sport', 'play'}
# Winnie the Pooh eating -> {'physiology'}
# Winnie the Pooh picking -> {'factotum'}
# Winnie the Pooh skills -> {'factotum'}
# Winnie the Pooh finds -> {'factotum'}
# Winnie the Pooh fight -> {'factotum'}
# Winnie the Pooh trap -> {'factotum'}
# Winnie the Pooh balloon -> {'play'}
# Winnie the Pooh interpretations -> {'factotum'}
# Winnie the Pooh wants -> {'finance'}
# Winnie the Pooh goes -> {'time_period'}
# Winnie the Pooh drawing -> {'drawing', 'publishing'}
# Winnie the Pooh found -> {'economy'}
# Winnie the Pooh reading -> {'linguistics'}
# Winnie the Pooh call -> {'telephony'}
# Winnie the Pooh hunger -> {'physiology'}
# Winnie the Pooh imagination -> {'factotum'}
# Winnie the Pooh rescue -> {'factotum'}
# Winnie the Pooh comprehension -> {'psychology'}
# Winnie the Pooh attempts -> {'factotum'}
# Winnie the Pooh lead -> {'chemistry'}
# Winnie the Pooh tries -> {'factotum'}
# Winnie the Pooh fall -> {'time_period'}
# Winnie the Pooh anchor -> {'nautical', 'fashion', 'mechanics'}
# Winnie the Pooh try -> {'factotum'}
# Winnie the Pooh left -> {'factotum'}
# Winnie the Pooh door -> {'vehicles', 'buildings'}
# Winnie the Pooh says -> {'factotum'}
# Winnie the Pooh figures -> {'publishing'}
# Winnie the Pooh selflessness -> {'quality'}
# Winnie the Pooh use -> {'factotum'}
# Winnie the Pooh sharing -> {'biology'}
# Winnie the Pooh replacement -> {'factotum'}
# Winnie the Pooh
# Counter({'factotum': 43,
#          'publishing': 5,
#          'law': 3,
#          'person': 3,
#          'fashion': 3,
#          'linguistics': 3,
#          'geology': 2,
#          'sport': 2,
#          'gastronomy': 2,
#          'telephony': 2,
#          'play': 2,
#          'physiology': 2,
#          'time_period': 2,
#          'tax': 1,
#          'psychological_features': 1,
#          'military': 1,
#          'administration': 1,
#          'town_planning': 1,
#          'medicine': 1,
#          'racing': 1,
#          'sociology': 1,
#          'anatomy': 1,
#          'animals': 1,
#          'post': 1,
#          'finance': 1,
#          'drawing': 1,
#          'economy': 1,
#          'psychology': 1,
#          'chemistry': 1,
#          'nautical': 1,
#          'mechanics': 1,
#          'vehicles': 1,
#          'buildings': 1,
#          'quality': 1,
#          'biology': 1})
# Ralph Breaks the Internet saves -> {'sport'}
# Ralph Breaks the Internet web -> {'factotum'}
# Ralph Breaks the Internet site -> {'factotum'}
# Ralph Breaks the Internet go -> {'time_period'}
# Ralph Breaks the Internet console -> {'furniture'}
# Ralph Breaks the Internet virus -> {'factotum'}
# Ralph Breaks the Internet feeds -> {'food'}
# Ralph Breaks the Internet rush -> {'factotum'}
# Ralph Breaks the Internet content -> {'factotum'}
# Ralph Breaks the Internet escape -> {'factotum'}
# Ralph Breaks the Internet break -> {'factotum'}
# Ralph Breaks the Internet gives -> {'physics'}
# Ralph Breaks the Internet internet -> {'computer_science'}
# Ralph Breaks the Internet firewall -> {'factotum'}
# Ralph Breaks the Internet player -> {'play'}
# Ralph Breaks the Internet purchase -> {'economy'}
# Ralph Breaks the Internet vendor -> {'commerce'}
# Ralph Breaks the Internet getting -> {'factotum'}
# Ralph Breaks the Internet crash -> {'factotum'}
# Ralph Breaks the Internet activities -> {'factotum'}
# Ralph Breaks the Internet duplicates -> {'factotum'}
# Ralph Breaks the Internet makes -> {'factotum'}
# Ralph Breaks the Internet monster -> {'factotum'}
# Ralph Breaks the Internet novelty -> {'factotum'}
# Ralph Breaks the Internet money -> {'money'}
# Ralph Breaks the Internet takes -> {'money'}
# Ralph Breaks the Internet friends -> {'person'}
# Ralph Breaks the Internet engine -> {'mechanics'}
# Ralph Breaks the Internet leave -> {'factotum'}
# Ralph Breaks the Internet making -> {'fashion'}
# Ralph Breaks the Internet insecurities -> {'factotum'}
# Ralph Breaks the Internet track -> {'factotum'}
# Ralph Breaks the Internet form -> {'linguistics'}
# Ralph Breaks the Internet winning -> {'factotum'}
# Ralph Breaks the Internet run -> {'sport', 'play'}
# Ralph Breaks the Internet breaks -> {'factotum'}
# Ralph Breaks the Internet price -> {'economy'}
# Ralph Breaks the Internet keep -> {'factotum'}
# Ralph Breaks the Internet idea -> {'factotum'}
# Ralph Breaks the Internet salesman -> {'commerce'}
# Ralph Breaks the Internet stealing -> {'law'}
# Ralph Breaks the Internet address -> {'computer_science'}
# Ralph Breaks the Internet make -> {'factotum'}
# Ralph Breaks the Internet cookie -> {'chemistry', 'food'}
# Ralph Breaks the Internet car -> {'transport', 'tourism'}
# Ralph Breaks the Internet slaughter -> {'enterprise', 'sociology'}
# Ralph Breaks the Internet touch -> {'factotum'}
# Ralph Breaks the Internet race -> {'sport', 'politics'}
# Ralph Breaks the Internet search -> {'factotum'}
# Ralph Breaks the Internet lead -> {'chemistry'}
# Ralph Breaks the Internet princesses -> {'heraldry'}
# Ralph Breaks the Internet talking -> {'factotum'}
# Ralph Breaks the Internet sugar -> {'gastronomy'}
# Ralph Breaks the Internet copies -> {'telecommunication'}
# Ralph Breaks the Internet end -> {'factotum'}
# Ralph Breaks the Internet film -> {'telecommunication', 'racing', 'sociology'}
# Ralph Breaks the Internet term -> {'linguistics'}
# Ralph Breaks the Internet character -> {'literature'}
# Ralph Breaks the Internet sharing -> {'biology'}
# Ralph Breaks the Internet stays -> {'fashion'}
# Ralph Breaks the Internet replacement -> {'factotum'}
# Ralph Breaks the Internet steering -> {'factotum'}
# Ralph Breaks the Internet expresses -> {'enterprise', 'transport'}
# Ralph Breaks the Internet server -> {'commerce'}
# Ralph Breaks the Internet overrun -> {'enterprise'}
# Ralph Breaks the Internet citizens -> {'town_planning', 'politics'}
# Ralph Breaks the Internet game -> {'sport'}
# Ralph Breaks the Internet resets -> {'mechanics'}
# Ralph Breaks the Internet help -> {'factotum'}
# Ralph Breaks the Internet choices -> {'factotum'}
# Ralph Breaks the Internet cost -> {'economy'}
# Ralph Breaks the Internet travel -> {'tourism'}
# Ralph Breaks the Internet fault -> {'psychological_features'}
# Ralph Breaks the Internet given -> {'factotum'}
# Ralph Breaks the Internet pop -> {'person'}
# Ralph Breaks the Internet chat -> {'factotum'}
# Ralph Breaks the Internet offers -> {'factotum'}
# Ralph Breaks the Internet views -> {'factotum'}
# Ralph Breaks the Internet starts -> {'factotum'}
# Ralph Breaks the Internet fights -> {'factotum'}
# Ralph Breaks the Internet lure -> {'factotum'}
# Ralph Breaks the Internet company -> {'enterprise'}
# Ralph Breaks the Internet throws -> {'factotum'}
# Ralph Breaks the Internet control -> {'factotum'}
# Ralph Breaks the Internet ends -> {'factotum'}
# Ralph Breaks the Internet bid -> {'factotum'}
# Ralph Breaks the Internet hanging -> {'architecture'}
# Ralph Breaks the Internet fulfillment -> {'psychological_features'}
# Ralph Breaks the Internet work -> {'factotum'}
# Ralph Breaks the Internet auction -> {'card'}
# Ralph Breaks the Internet epiphany -> {'factotum'}
# Ralph Breaks the Internet hours -> {'time_period'}
# Ralph Breaks the Internet video -> {'telecommunication', 'radio+tv'}
# Ralph Breaks the Internet job -> {'factotum'}
# Ralph Breaks the Internet reaching -> {'factotum'}
# Ralph Breaks the Internet feeling -> {'psychological_features'}
# Ralph Breaks the Internet characters -> {'literature'}
# Ralph Breaks the Internet funds -> {'finance'}
# Ralph Breaks the Internet friendship -> {'factotum'}
# Ralph Breaks the Internet tells -> {'archery', 'history'}
# Ralph Breaks the Internet time -> {'factotum'}
# Ralph Breaks the Internet save -> {'sport'}
# Ralph Breaks the Internet check -> {'banking'}
# Ralph Breaks the Internet sense -> {'factotum'}
# Ralph Breaks the Internet attack -> {'factotum'}
# Ralph Breaks the Internet years -> {'time_period'}
# Ralph Breaks the Internet homes -> {'factotum'}
# Ralph Breaks the Internet finds -> {'factotum'}
# Ralph Breaks the Internet ability -> {'factotum'}
# Ralph Breaks the Internet causing -> {'factotum'}
# Ralph Breaks the Internet device -> {'factotum'}
# Ralph Breaks the Internet glitch -> {'computer_science', 'mechanics'}
# Ralph Breaks the Internet tracks -> {'factotum'}
# Ralph Breaks the Internet ways -> {'factotum'}
# Ralph Breaks the Internet head -> {'anatomy', 'animals'}
# Ralph Breaks the Internet contacts -> {'factotum'}
# Ralph Breaks the Internet found -> {'economy'}
# Ralph Breaks the Internet steal -> {'factotum'}
# Ralph Breaks the Internet way -> {'factotum'}
# Ralph Breaks the Internet measure -> {'metrology'}
# Ralph Breaks the Internet router -> {'factotum'}
# Ralph Breaks the Internet attempts -> {'factotum'}
# Ralph Breaks the Internet clones -> {'person'}
# Ralph Breaks the Internet scrap -> {'factotum'}
# Ralph Breaks the Internet fix -> {'factotum'}
# Ralph Breaks the Internet draw -> {'geology', 'geography'}
# Ralph Breaks the Internet wheel -> {'transport', 'mechanics'}
# Ralph Breaks the Internet letting -> {'economy'}
# Ralph Breaks the Internet day -> {'factotum'}
# Ralph Breaks the Internet stops -> {'card'}
# Ralph Breaks the Internet figure -> {'publishing'}
# Ralph Breaks the Internet
# Counter({'factotum': 65,
#          'sport': 5,
#          'economy': 5,
#          'mechanics': 4,
#          'enterprise': 4,
#          'time_period': 3,
#          'computer_science': 3,
#          'commerce': 3,
#          'person': 3,
#          'transport': 3,
#          'telecommunication': 3,
#          'psychological_features': 3,
#          'food': 2,
#          'play': 2,
#          'money': 2,
#          'fashion': 2,
#          'linguistics': 2,
#          'chemistry': 2,
#          'tourism': 2,
#          'sociology': 2,
#          'politics': 2,
#          'literature': 2,
#          'card': 2,
#          'furniture': 1,
#          'physics': 1,
#          'law': 1,
#          'heraldry': 1,
#          'gastronomy': 1,
#          'racing': 1,
#          'biology': 1,
#          'town_planning': 1,
#          'architecture': 1,
#          'radio+tv': 1,
#          'finance': 1,
#          'archery': 1,
#          'history': 1,
#          'banking': 1,
#          'anatomy': 1,
#          'animals': 1,
#          'metrology': 1,
#          'geology': 1,
#          'geography': 1,
#          'publishing': 1})

# %%
full_df = pd.DataFrame(columns=['1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000', '2010'])

for dom, decs in dict_all_domains.items():
    full_df.loc[dom] = ['Y' if (str(dec) in decs) else 'N' for dec in range(1930, 2010 +1, 10)]
    
full_df.sort_index(inplace=True)

# %%
full_df
# Out:
#                        1930 1940 1950 1960 1970 1980 1990 2000 2010
# administration            N    N    Y    Y    Y    N    N    Y    N
# anatomy                   N    N    N    N    N    Y    N    N    Y
# animals                   Y    N    Y    Y    Y    Y    N    Y    N
# biology                   Y    N    Y    Y    Y    Y    Y    Y    Y
# buildings                 Y    N    Y    Y    Y    Y    N    Y    N
# chemistry                 Y    N    Y    N    Y    N    N    Y    Y
# commerce                  Y    N    N    N    N    N    N    N    N
# dance                     Y    N    N    N    N    N    N    N    N
# economy                   Y    N    N    Y    Y    Y    Y    Y    Y
# electricity               Y    N    N    N    N    N    N    N    N
# exchange                  Y    N    N    N    N    N    N    N    N
# factotum                  Y    N    Y    Y    Y    Y    Y    Y    Y
# finance                   Y    N    N    N    N    N    N    N    N
# food                      Y    N    N    N    N    N    N    N    N
# free_time                 N    N    Y    N    N    N    N    N    N
# furniture                 Y    N    N    N    N    N    N    N    N
# gastronomy                Y    N    N    N    N    N    N    N    N
# geography                 Y    N    Y    Y    N    Y    N    Y    Y
# geology                   Y    N    N    Y    N    N    N    N    N
# heraldry                  Y    N    N    N    N    N    N    N    N
# history                   N    N    Y    Y    N    Y    Y    Y    Y
# jewellery                 Y    N    N    N    N    N    N    N    N
# law                       Y    N    Y    Y    Y    Y    Y    Y    Y
# literature                Y    N    N    Y    Y    N    N    N    N
# medicine                  Y    N    N    N    N    Y    Y    N    N
# meteorology               Y    N    N    N    N    N    N    N    N
# metrology                 Y    N    N    N    Y    Y    N    N    N
# military                  Y    N    Y    Y    N    Y    N    Y    Y
# money                     Y    N    Y    Y    Y    Y    Y    N    N
# music                     Y    N    N    N    Y    N    N    N    N
# nautical                  N    N    N    Y    N    N    N    N    N
# person                    Y    N    Y    Y    Y    Y    Y    Y    Y
# physics                   Y    N    N    N    N    N    N    Y    N
# physiology                Y    N    Y    N    N    N    N    N    N
# plants                    Y    N    Y    Y    N    N    N    Y    N
# politics                  N    N    Y    N    N    Y    N    N    Y
# psychological_features    Y    N    Y    Y    N    N    Y    Y    Y
# psychology                Y    N    N    N    N    N    N    N    N
# racing                    Y    N    N    N    N    N    N    N    N
# religion                  Y    N    N    N    N    N    N    N    N
# sociology                 Y    N    Y    Y    N    Y    Y    Y    Y
# sport                     Y    N    N    N    Y    Y    N    Y    Y
# tax                       Y    N    N    N    Y    N    Y    N    Y
# telecommunication         Y    N    N    N    N    N    N    N    N
# theatre                   Y    N    N    N    N    N    N    N    N
# time_period               Y    N    Y    Y    Y    Y    Y    Y    Y
# tourism                   Y    N    Y    N    N    Y    Y    Y    Y
# town_planning             N    N    Y    N    N    Y    Y    N    Y
# transport                 N    N    Y    N    Y    Y    Y    Y    Y

# %%
# DA NON FARE ANDARE
#tentativo inutile e cmq non riuscito cmq di ordinare per anno
df=df.fillna(0)
columns=list(df.columns)

for column in columns:
    year = 1930
    for j in range (0, 9):
        if df.iloc[j, df.columns.get_loc(column)] == 0:
            year+=1
            continue
        df.iloc[j, df.columns.get_loc(column)] = year
        year += 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-47f9d38f88d1> in <module>
#       1 # DA NON FARE ANDARE
#       2 #tentativo inutile e cmq non riuscito cmq di ordinare per anno
# ----> 3 df=df.fillna(0)
#       4 columns=list(df.columns)
#       5
#
# NameError: name 'df' is not defined

# %%
df_null = df.isnull().sum(axis = 0)
df_null=df_null.to_frame().reset_index()

# %%
df_null.rename(columns={'index': 'domain', 0:'counts'}, inplace=True)
df_null
# Out:
#            domain  counts
# 0         tourism       0
# 1          plants       0
# 2   town_planning       0
# 3         economy       0
# 4        military       0
# ..            ...     ...
# 91           golf       8
# 92     philosophy       8
# 93     hydraulics       8
# 94           card       8
# 95         health       8
#
# [96 rows x 2 columns]

# %%
# se uno vuol fare dei check sui valori nulli (ossia )
for g in range (0,95):
    if df_null['counts'][g] > 5:
        print(df_null['domain'][g])
# Out:
# agriculture
# acoustics
# betting
# hunting
# sexuality
# electricity
# grammar
# computer_science
# football
# pedagogy
# occultism
# painting
# swimming
# vehicles
# post
# telephony
# enterprise
# telegraphy
# geometry
# atomic_physic
# earth
# optics
# golf
# philosophy
# hydraulics
# card

# %%
df.to_csv(r"/Users/valeriaguttilla/Desktop/MASTER/PROGETTONE/ANALISI_TESTUALE/ANALISI TRAME/TRAME/ANIMATED/csv_trame.csv")
