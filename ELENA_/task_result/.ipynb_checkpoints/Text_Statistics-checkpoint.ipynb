# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('normalized_texts.csv')

# %%
df.head()
# Out:
#                                                Title    House  Decade  Year  \
# 0                                        Chicken Run  Aardman    2000  2000
# 1                                       Flushed Away  Aardman    2000  2006
# 2  Wallace And Gromit In The Curse Of The Were-Ra...  Aardman    2000  2005
# 3                                   Arthur Christmas  Aardman    2010  2011
# 4                                          Early Man  Aardman    2010  2018
#
#     Category  Movie_len  Avg_WordLen_Movie  Avg_PhrLen_Movie  \
# 0  Animation   0.197392           0.371134          0.197756
# 1  Animation   0.296538           0.319588          0.182328
# 2  Animation   0.071493           0.876289          0.267882
# 3  Animation   0.388939           0.381443          0.164095
# 4  Animation   0.227518           0.402062          0.117812
#
#    Avg_WordLen_Phrase  Num_Adjectives  Num_Adverbs
# 0            0.710526        0.229044     0.226182
# 1            0.689474        0.402597     0.309818
# 2            0.873684        0.157025     0.094545
# 3            0.863158        0.422668     0.381818
# 4            0.805263        0.233766     0.208727

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 11 columns):
# Title                 432 non-null object
# House                 432 non-null object
# Decade                432 non-null int64
# Year                  432 non-null int64
# Category              432 non-null object
# Movie_len             432 non-null float64
# Avg_WordLen_Movie     432 non-null float64
# Avg_PhrLen_Movie      432 non-null float64
# Avg_WordLen_Phrase    432 non-null float64
# Num_Adjectives        432 non-null float64
# Num_Adverbs           432 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 37.2+ KB

# %%
v_name = []
v_type = []
v_domain = []
v_is_null = []
for c in df.columns:
    col_list = df[c]
    v_name.append(c)
    v_type.append(type(col_list[0]))
    v_domain.append(sorted(col_list.unique()))
    v_is_null.append(col_list.isnull().any())
    
d = {'variable': v_name, 'type': v_type, 'domain': v_domain, 'any_null': v_is_null}
pd.DataFrame(data=d).set_index('variable')
# Out:
#                                        type  \
# variable
# Title                         <class 'str'>
# House                         <class 'str'>
# Decade                <class 'numpy.int64'>
# Year                  <class 'numpy.int64'>
# Category                      <class 'str'>
# Movie_len           <class 'numpy.float64'>
# Avg_WordLen_Movie   <class 'numpy.float64'>
# Avg_PhrLen_Movie    <class 'numpy.float64'>
# Avg_WordLen_Phrase  <class 'numpy.float64'>
# Num_Adjectives      <class 'numpy.float64'>
# Num_Adverbs         <class 'numpy.float64'>
#
#                                                                domain  \
# variable
# Title               [101 Dalmatians, 102 Dalmatians, A Bug's Life,...
# House               [Aardman, Blue, Disney, Dreamworks, Illuminati...
# Decade              [1930, 1940, 1950, 1960, 1970, 1980, 1990, 200...
# Year                [1937, 1940, 1941, 1942, 1943, 1944, 1946, 194...
# Category            [Animation, Animation + Live Action, Live Action]
# Movie_len           [0.0, 0.0024730215827338115, 0.022931654676259...
# Avg_WordLen_Movie   [0.0, 0.04123711340206171, 0.07216494845360799...
# Avg_PhrLen_Movie    [0.0, 0.021037868162692874, 0.0294530154277700...
# Avg_WordLen_Phrase  [0.0, 0.13684210526315765, 0.16842105263157925...
# Num_Adjectives      [0.0, 0.005903187721369539, 0.0094451003541912...
# Num_Adverbs         [0.0, 0.007272727272727274, 0.0080000000000000...
#
#                     any_null
# variable
# Title                  False
# House                  False
# Decade                 False
# Year                   False
# Category               False
# Movie_len              False
# Avg_WordLen_Movie      False
# Avg_PhrLen_Movie       False
# Avg_WordLen_Phrase     False
# Num_Adjectives         False
# Num_Adverbs            False

# %%
df_disney_tot=df[(df['House'] == 'Disney')]
df_disney=df[(df['House'] == 'Disney') & (df['Category'] == 'Animation')]
df_disney_liveaction=df[(df['House'] == 'Disney') & (df['Category'] == 'Live Action')]
df_disney_la=df[(df['House'] == 'Disney') & (df['Category'] == 'Animation + Live Action')]
df_aardman=df[df['House'] == 'Aardman']
df_blue=df[df['House'] == 'Blue']
df_dreamworks=df[df['House'] == 'Dreamworks']
df_illumination=df[df['House'] == 'Illumination']
df_paramount=df[df['House'] == 'Paramount']
df_sony=df[df['House'] == 'Sony']
df_studioghibli=df[df['House'] == 'StudioGhibli']
df_universal=df[df['House'] == 'Universal']

# %%
df_paramount.head()
# Out:
#                                        Title      House  Decade  Year  \
# 367                           Monster Trucks  Paramount    2010  2016
# 368                          Sherlock Gnomes  Paramount    2010  2018
# 369  The SpongeBob Movie Sponge Out of Water  Paramount    2010  2015
# 370                              Wonder Park  Paramount    2010  2019
#
#       Category  Movie_len  Avg_WordLen_Movie  Avg_PhrLen_Movie  \
# 367  Animation   0.226169           0.247423          0.244039
# 368  Animation   0.338129           0.422680          0.228612
# 369  Animation   0.273381           0.494845          0.300140
# 370  Animation   0.286421           0.422680          0.252454
#
#      Avg_WordLen_Phrase  Num_Adjectives  Num_Adverbs
# 367            0.578947        0.211334     0.320000
# 368            0.694737        0.451004     0.410909
# 369            0.763158        0.367178     0.329455
# 370            0.689474        0.370720     0.346909

# %% [markdown]
# ### Plot Indici tutti insieme (Disney Animation)
# #### Andamento per decade

# %%
#selezione delle colonne con gli indici
indexes=[c for c in df_disney.columns if c not in ['Title', 'House', 'Category', 'Decade', 'Year']]
#raggruppamento per decade e media degli indici
meandf=df_disney[indexes+['Decade']].groupby(['Decade']).agg([np.mean, np.std])

# %%
df_disney.columns.values
# Out:
# array(['Title', 'House', 'Decade', 'Year', 'Category', 'Movie_len',
#        'Avg_WordLen_Movie', 'Avg_PhrLen_Movie', 'Avg_WordLen_Phrase',
#        'Num_Adjectives', 'Num_Adverbs'], dtype=object)

# %%
meandf.head()
# Out:
#        Movie_len           Avg_WordLen_Movie           Avg_PhrLen_Movie  \
#             mean       std              mean       std             mean
# Decade
# 1930    0.190647       NaN          0.164948       NaN         0.166900
# 1940    0.170020  0.093668          0.448454  0.179057         0.254909
# 1950    0.249955  0.048613          0.371134  0.082474         0.198597
# 1960    0.284772  0.005742          0.302405  0.051889         0.198223
# 1970    0.248932  0.050212          0.412371  0.049799         0.225456
#
#                  Avg_WordLen_Phrase           Num_Adjectives            \
#              std               mean       std           mean       std
# Decade
# 1930         NaN           0.578947       NaN       0.247934       NaN
# 1940    0.182049           0.692105  0.159263       0.275384  0.145362
# 1950    0.028427           0.657895  0.065526       0.328217  0.055049
# 1960    0.044381           0.708772  0.186996       0.405746  0.035524
# 1970    0.053264           0.721053  0.111896       0.390791  0.086151
#
#        Num_Adverbs
#               mean       std
# Decade
# 1930      0.194909       NaN
# 1940      0.185455  0.088912
# 1950      0.279564  0.044066
# 1960      0.317818  0.022392
# 1970      0.312182  0.080324

# %%
for i in indexes: 

    y=meandf[i]['mean'].values #dal df raggruppato prendo i valori di tutti gli indici
    #print(y)
    x=meandf.index.values #prendo i valori (cioè le decadi) dall'indice del df raggruppato
    #print(x)
    plt.plot(x,y)
    plt.legend(indexes, loc='center right')
plt.show()

# %% [markdown]
# ### Matrice dei sei indici per decade per tutte le case (solo Animazione)

# %%
dataframe_list=df_list=[df_disney, df_aardman, df_blue, df_dreamworks, df_illumination, df_paramount, df_sony, df_studioghibli, df_universal]

# %%
plt.figure(figsize=(18,18))
i=1
for ind in indexes:
    plt.subplot(2,3,i)
    for dataframe in df_list:
        meandf=dataframe[indexes+['Decade']].groupby(['Decade']).agg([np.mean, np.std])
        y=meandf[ind]['mean'].values 
        x=meandf.index.values 
        plt.plot(x,y)
        #plt.legend(houses, loc='center right')
    i+=1
plt.show()

# %% [markdown]
# ### Matrice di tutti gli indici per la Disney (per categoria e per decade)

# %%
disney_df_list=[df_disney, df_disney_liveaction, df_disney_la]

# %%
plt.figure(figsize=(18,18))
i=1
for ind in indexes:
    plt.subplot(2,3,i)
    for dataframe in disney_df_list:
        meandf=dataframe[indexes+['Decade']].groupby(['Decade']).agg([np.mean, np.std])
        y=meandf[ind]['mean'].values 
        x=meandf.index.values 
        plt.plot(x,y)
        #plt.legend(dataframe['Category'].values, loc='center right')
    i+=1
plt.show()

# %% [markdown]
# ### Matrice delle case (Movie_len)

# %%
df_list=[df_disney, df_disney_liveaction, df_disney_la, df_aardman, df_blue, df_dreamworks, df_illumination, df_paramount, df_sony, df_studioghibli, df_universal]

# %%
plt.figure(figsize=(18,18))
i=1
for dataframe in df_list:
    
    indexes=dataframe['Movie_len'].values
    meandf=dataframe[['Movie_len','Decade']].groupby(['Decade']).agg(np.mean)

    y=meandf.values
    x=meandf.index.values
    plt.subplot(4,3,i)
    #print(y)
    #print(x)
    plt.plot(x,y)
    i+=1

plt.show()

# %% [markdown]
# ### Matrice delle case (Average Phrase Length)

# %%
plt.figure(figsize=(18,18))
i=1
for dataframe in df_list:
    
    indexes=dataframe['Avg_PhrLen_Movie'].values
    meandf=dataframe[['Avg_PhrLen_Movie','Decade']].groupby(['Decade']).agg(np.mean)

    y=meandf.values
    x=meandf.index.values
    plt.subplot(4,3,i)
    #print(y)
    #print(x)
    plt.plot(x,y)
    i+=1

plt.show()

# %% [markdown]
# ## Distribuzione Movie_len per i film di animazione Disney per decade

# %%
plt.figure(figsize=(18,18))
#fig, ax = plt.subplots()

i=1
for d in range(1940,2010 +1,10):
    ddf=df_disney[df_disney['Decade']== d]
    x=ddf['Movie_len'].values
    ax=plt.subplot(3,3,i)  
    movies= ddf['Title'].values
    y_pos = np.arange(len(movies))
    ax.set_yticks(y_pos)
    ax.set_yticklabels(movies)
    length=x
    ax.barh(y_pos, length, align='center')  
        
    i+=1
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18,36))

df_disney.sort_values(by=['Decade','Movie_len'], inplace= True, ascending=False)
x=df_disney['Movie_len'].values 
movies= df_disney['Title'].values
y_pos = np.arange(len(movies))
ax.set_yticks(y_pos)
ax.set_yticklabels(movies)
length=x
ax.barh(y_pos, length, align='center')  

plt.show()
# Out:
# C:\Users\Amministratore\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
