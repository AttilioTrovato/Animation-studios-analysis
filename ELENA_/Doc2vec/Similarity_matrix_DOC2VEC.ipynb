# %%
import numpy as np
import scipy as sc
import pandas as pd
import csv
from scipy.sparse import csr_matrix
import re
import os
from gensim.test.utils import common_texts
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
import json

# %%
input_file='disney_anim.csv'

# %%
df=pd.read_csv(input_file)

# %%
df.head()
# Out:
#                                    Title   House  Decade  Year   Category  \
# 0        Snow White and the Seven Dwarfs  Disney    1930  1937  Animation
# 1                                  Bambi  Disney    1940  1942  Animation
# 2                                  Dumbo  Disney    1940  1941  Animation
# 3                              Pinocchio  Disney    1940  1940  Animation
# 4  The Adventures of Ichabod and Mr Toad  Disney    1940  1949  Animation
#
#                                                 Text
# 0  Slave in the Magic Mirror, come from the farth...
# 1  Love is a song that never ends  Life may be sw...
# 2  Through the snow and sleet and hail... through...
# 3   When you wish upon a star   Makes no differen...
# 4  Ichabod and Mr Toad  Ichabod  Ichabod and Mr T...

# %%
ddf=df.drop(['House', 'Year', 'Category', 'Text'], axis=1)

# %%
ddf.head()
# Out:
#                                    Title  Decade
# 0        Snow White and the Seven Dwarfs    1930
# 1                                  Bambi    1940
# 2                                  Dumbo    1940
# 3                              Pinocchio    1940
# 4  The Adventures of Ichabod and Mr Toad    1940

# %%
dd={}
for element in ddf.values:
        key=element[0]
        value=element[1]
        dd[key]=value

# %%
dd
# Out:
# {'Snow White and the Seven Dwarfs': 1930,
#  'Bambi': 1940,
#  'Dumbo': 1940,
#  'Pinocchio': 1940,
#  'The Adventures of Ichabod and Mr Toad': 1940,
#  'Alice in Wonderland': 1950,
#  'Cinderella': 1950,
#  'Lady and the Tramp': 1950,
#  'Peter Pan': 1950,
#  'Sleeping Beauty': 1950,
#  'One Hundred and One Dalmatians': 1960,
#  'The Jungle Book': 1960,
#  'The Sword in the Stone': 1960,
#  'Robin Hood': 1970,
#  'The AristoCats': 1970,
#  'The Rescuers': 1970,
#  'Winnie the Pooh': 2010,
#  'Oliver and Company': 1980,
#  'The Black Cauldrion': 1980,
#  'The Fox And The Hound': 1980,
#  'The Great Mouse Detective': 1980,
#  'The Little Mermaid': 1980,
#  "A Bug's Life": 1990,
#  'A Goofy Movie': 1990,
#  'Aladdin': 1990,
#  'Beauty and the Beast': 1990,
#  'DuckTales The Movie - Treasure of the Lost Lamp': 1990,
#  'Hercules': 1990,
#  'Mulan': 1990,
#  'Pocahontas': 1990,
#  'Tarzan': 1990,
#  'The Hunchback of Notre Dame': 1990,
#  'The Lion King': 1990,
#  'The Nightmare Before Christmas': 1990,
#  'The Rescuers Down Under': 1990,
#  'Toy Story 2': 1990,
#  'Toy Story': 1990,
#  'A Christmas Carol': 2000,
#  'Atlantis-The Lost Empire': 2000,
#  'Bolt': 2000,
#  'Brother Bear': 2000,
#  'Cars': 2000,
#  'Chicken Little': 2000,
#  'Dinosaur': 2000,
#  'Finding Nemo': 2000,
#  'Home on the Range': 2000,
#  'Lilo And Stitch': 2000,
#  'Meet the Robinsons': 2000,
#  'Monsters Inc': 2000,
#  'Piglets Big Movie': 2000,
#  'Ratatouille': 2000,
#  'Recess Schools Out': 2000,
#  'Return to Never Land': 2000,
#  'The Emperors New Groove': 2000,
#  'The Incredibles': 2000,
#  'The Jungle Book 2': 2000,
#  'The Princess And The Frog': 2000,
#  'The Tigger Movie': 2000,
#  'The Wild': 2000,
#  'Treasure Planet': 2000,
#  'Up': 2000,
#  'Valiant': 2000,
#  'WALL-E': 2000,
#  'Arjun The Warrior Prince': 2010,
#  'Big Hero 6': 2010,
#  'Brave': 2010,
#  'Cars 2': 2010,
#  'Cars 3': 2010,
#  'Coco': 2010,
#  'Finding Dory': 2010,
#  'Frankenweenie': 2010,
#  'Frozen 2': 2010,
#  'Frozen': 2010,
#  'Incredibles 2': 2010,
#  'Inside Out': 2010,
#  'Mars Needs Moms': 2010,
#  'Moana': 2010,
#  'Monsters University': 2010,
#  'Planes Fire and Rescue': 2010,
#  'Planes': 2010,
#  'Ralph Breaks The Internet': 2010,
#  'Tangled': 2010,
#  'The Good Dinosaur': 2010,
#  'Toy Story 3': 2010,
#  'Toy Story 4': 2010,
#  'Wreck it Ralph': 2010,
#  'Zootopia': 2010}

# %%
data=[]
with open(input_file, encoding='utf-8', newline='') as handle:
    reader = csv.reader(handle)
    for row in reader:
        data.append(TaggedDocument(re.split('[\W\d_]+',row[5].lower()),[row[0]]))

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
model= Doc2Vec(data, vector_size=150, window=10, min_count=5)
# Out:
# 2020-06-24 16:18:41,843 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-06-24 16:18:41,850 : INFO : collecting all words and their counts
# 2020-06-24 16:18:41,850 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-06-24 16:18:42,123 : INFO : collected 21961 word types and 88 unique tags from a corpus of 89 examples and 630092 words
# 2020-06-24 16:18:42,123 : INFO : Loading a fresh vocabulary
# 2020-06-24 16:18:42,170 : INFO : effective_min_count=5 retains 6191 unique words (28% of original 21961, drops 15770)
# 2020-06-24 16:18:42,171 : INFO : effective_min_count=5 leaves 604839 word corpus (95% of original 630092, drops 25253)
# 2020-06-24 16:18:42,246 : INFO : deleting the raw counts dictionary of 21961 items
# 2020-06-24 16:18:42,255 : INFO : sample=0.001 downsamples 67 most-common words
# 2020-06-24 16:18:42,255 : INFO : downsampling leaves estimated 426626 word corpus (70.5% of prior 604839)
# 2020-06-24 16:18:42,317 : INFO : estimated required memory for 6191 words and 150 dimensions: 10595100 bytes
# 2020-06-24 16:18:42,323 : INFO : resetting layer weights
# 2020-06-24 16:18:42,540 : INFO : training model with 3 workers on 6191 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-06-24 16:18:43,562 : INFO : EPOCH 1 - PROGRESS: at 94.38% examples, 394735 words/s, in_qsize 5, out_qsize 0
# 2020-06-24 16:18:43,593 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-24 16:18:43,613 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-24 16:18:43,625 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-24 16:18:43,628 : INFO : EPOCH - 1 : training on 630092 raw words (426720 effective words) took 1.1s, 399061 effective words/s
# 2020-06-24 16:18:44,649 : INFO : EPOCH 2 - PROGRESS: at 93.26% examples, 380507 words/s, in_qsize 6, out_qsize 0
# 2020-06-24 16:18:44,691 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-24 16:18:44,705 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-24 16:18:44,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-24 16:18:44,727 : INFO : EPOCH - 2 : training on 630092 raw words (426105 effective words) took 1.1s, 389924 effective words/s
# 2020-06-24 16:18:45,747 : INFO : EPOCH 3 - PROGRESS: at 93.26% examples, 379601 words/s, in_qsize 5, out_qsize 0
# 2020-06-24 16:18:45,795 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-24 16:18:45,810 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-24 16:18:45,838 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-24 16:18:45,842 : INFO : EPOCH - 3 : training on 630092 raw words (426924 effective words) took 1.1s, 385079 effective words/s
# 2020-06-24 16:18:46,853 : INFO : EPOCH 4 - PROGRESS: at 92.13% examples, 387400 words/s, in_qsize 5, out_qsize 0
# 2020-06-24 16:18:46,896 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-24 16:18:46,906 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-24 16:18:46,929 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-24 16:18:46,929 : INFO : EPOCH - 4 : training on 630092 raw words (426502 effective words) took 1.1s, 393062 effective words/s
# 2020-06-24 16:18:47,962 : INFO : EPOCH 5 - PROGRESS: at 92.13% examples, 377166 words/s, in_qsize 6, out_qsize 0
# 2020-06-24 16:18:48,003 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-24 16:18:48,036 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-24 16:18:48,042 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-24 16:18:48,046 : INFO : EPOCH - 5 : training on 630092 raw words (426265 effective words) took 1.1s, 385001 effective words/s
# 2020-06-24 16:18:48,047 : INFO : training on a 3150460 raw words (2132516 effective words) took 5.5s, 388239 effective words/s

# %%
movies=list(model.docvecs.doctags.keys())

# %%
movies.remove('Title')

# %%
movies[0]
# Out:
# 'Snow White and the Seven Dwarfs'

# %%
vocab={}
for movie in movies:
    if movie not in vocab:
        vocab[movie] = len(vocab)

# %%
vocab
# Out:
# {'Snow White and the Seven Dwarfs': 0,
#  'Bambi': 1,
#  'Dumbo': 2,
#  'Pinocchio': 3,
#  'The Adventures of Ichabod and Mr Toad': 4,
#  'Alice in Wonderland': 5,
#  'Cinderella': 6,
#  'Lady and the Tramp': 7,
#  'Peter Pan': 8,
#  'Sleeping Beauty': 9,
#  'One Hundred and One Dalmatians': 10,
#  'The Jungle Book': 11,
#  'The Sword in the Stone': 12,
#  'Robin Hood': 13,
#  'The AristoCats': 14,
#  'The Rescuers': 15,
#  'Winnie the Pooh': 16,
#  'Oliver and Company': 17,
#  'The Black Cauldrion': 18,
#  'The Fox And The Hound': 19,
#  'The Great Mouse Detective': 20,
#  'The Little Mermaid': 21,
#  "A Bug's Life": 22,
#  'A Goofy Movie': 23,
#  'Aladdin': 24,
#  'Beauty and the Beast': 25,
#  'DuckTales The Movie - Treasure of the Lost Lamp': 26,
#  'Hercules': 27,
#  'Mulan': 28,
#  'Pocahontas': 29,
#  'Tarzan': 30,
#  'The Hunchback of Notre Dame': 31,
#  'The Lion King': 32,
#  'The Nightmare Before Christmas': 33,
#  'The Rescuers Down Under': 34,
#  'Toy Story 2': 35,
#  'Toy Story': 36,
#  'A Christmas Carol': 37,
#  'Atlantis-The Lost Empire': 38,
#  'Bolt': 39,
#  'Brother Bear': 40,
#  'Cars': 41,
#  'Chicken Little': 42,
#  'Dinosaur': 43,
#  'Finding Nemo': 44,
#  'Home on the Range': 45,
#  'Lilo And Stitch': 46,
#  'Meet the Robinsons': 47,
#  'Monsters Inc': 48,
#  'Piglets Big Movie': 49,
#  'Ratatouille': 50,
#  'Recess Schools Out': 51,
#  'Return to Never Land': 52,
#  'The Emperors New Groove': 53,
#  'The Incredibles': 54,
#  'The Jungle Book 2': 55,
#  'The Princess And The Frog': 56,
#  'The Tigger Movie': 57,
#  'The Wild': 58,
#  'Treasure Planet': 59,
#  'Up': 60,
#  'Valiant': 61,
#  'WALL-E': 62,
#  'Arjun The Warrior Prince': 63,
#  'Big Hero 6': 64,
#  'Brave': 65,
#  'Cars 2': 66,
#  'Cars 3': 67,
#  'Coco': 68,
#  'Finding Dory': 69,
#  'Frankenweenie': 70,
#  'Frozen 2': 71,
#  'Frozen': 72,
#  'Incredibles 2': 73,
#  'Inside Out': 74,
#  'Mars Needs Moms': 75,
#  'Moana': 76,
#  'Monsters University': 77,
#  'Planes Fire and Rescue': 78,
#  'Planes': 79,
#  'Ralph Breaks The Internet': 80,
#  'Tangled': 81,
#  'The Good Dinosaur': 82,
#  'Toy Story 3': 83,
#  'Toy Story 4': 84,
#  'Wreck it Ralph': 85,
#  'Zootopia': 86}

# %%
reverse_vocab = {}
for movie, movieID in vocab.items():
    reverse_vocab[movieID] = movie

# %%
reverse_vocab
# Out:
# {0: 'Snow White and the Seven Dwarfs',
#  1: 'Bambi',
#  2: 'Dumbo',
#  3: 'Pinocchio',
#  4: 'The Adventures of Ichabod and Mr Toad',
#  5: 'Alice in Wonderland',
#  6: 'Cinderella',
#  7: 'Lady and the Tramp',
#  8: 'Peter Pan',
#  9: 'Sleeping Beauty',
#  10: 'One Hundred and One Dalmatians',
#  11: 'The Jungle Book',
#  12: 'The Sword in the Stone',
#  13: 'Robin Hood',
#  14: 'The AristoCats',
#  15: 'The Rescuers',
#  16: 'Winnie the Pooh',
#  17: 'Oliver and Company',
#  18: 'The Black Cauldrion',
#  19: 'The Fox And The Hound',
#  20: 'The Great Mouse Detective',
#  21: 'The Little Mermaid',
#  22: "A Bug's Life",
#  23: 'A Goofy Movie',
#  24: 'Aladdin',
#  25: 'Beauty and the Beast',
#  26: 'DuckTales The Movie - Treasure of the Lost Lamp',
#  27: 'Hercules',
#  28: 'Mulan',
#  29: 'Pocahontas',
#  30: 'Tarzan',
#  31: 'The Hunchback of Notre Dame',
#  32: 'The Lion King',
#  33: 'The Nightmare Before Christmas',
#  34: 'The Rescuers Down Under',
#  35: 'Toy Story 2',
#  36: 'Toy Story',
#  37: 'A Christmas Carol',
#  38: 'Atlantis-The Lost Empire',
#  39: 'Bolt',
#  40: 'Brother Bear',
#  41: 'Cars',
#  42: 'Chicken Little',
#  43: 'Dinosaur',
#  44: 'Finding Nemo',
#  45: 'Home on the Range',
#  46: 'Lilo And Stitch',
#  47: 'Meet the Robinsons',
#  48: 'Monsters Inc',
#  49: 'Piglets Big Movie',
#  50: 'Ratatouille',
#  51: 'Recess Schools Out',
#  52: 'Return to Never Land',
#  53: 'The Emperors New Groove',
#  54: 'The Incredibles',
#  55: 'The Jungle Book 2',
#  56: 'The Princess And The Frog',
#  57: 'The Tigger Movie',
#  58: 'The Wild',
#  59: 'Treasure Planet',
#  60: 'Up',
#  61: 'Valiant',
#  62: 'WALL-E',
#  63: 'Arjun The Warrior Prince',
#  64: 'Big Hero 6',
#  65: 'Brave',
#  66: 'Cars 2',
#  67: 'Cars 3',
#  68: 'Coco',
#  69: 'Finding Dory',
#  70: 'Frankenweenie',
#  71: 'Frozen 2',
#  72: 'Frozen',
#  73: 'Incredibles 2',
#  74: 'Inside Out',
#  75: 'Mars Needs Moms',
#  76: 'Moana',
#  77: 'Monsters University',
#  78: 'Planes Fire and Rescue',
#  79: 'Planes',
#  80: 'Ralph Breaks The Internet',
#  81: 'Tangled',
#  82: 'The Good Dinosaur',
#  83: 'Toy Story 3',
#  84: 'Toy Story 4',
#  85: 'Wreck it Ralph',
#  86: 'Zootopia'}

# %%
matrix=np.zeros(shape=(len(movies), len(vocab)))

# %%
for index, key in enumerate(vocab):
    for index2, key2 in enumerate(vocab):
        matrix[index][index2] = model.docvecs.similarity(key, key2)
        
len(matrix)
# Out:
# 87

# %%
matrix
# Out:
# array([[1.        , 0.76984525, 0.68802172, ..., 0.37819093, 0.63876843,
#         0.67140722],
#        [0.76984525, 1.        , 0.8045665 , ..., 0.68034065, 0.91309166,
#         0.77241838],
#        [0.68802172, 0.8045665 , 1.        , ..., 0.52862561, 0.70069784,
#         0.72151709],
#        ...,
#        [0.37819093, 0.68034065, 0.52862561, ..., 1.        , 0.63058972,
#         0.35970801],
#        [0.63876843, 0.91309166, 0.70069784, ..., 0.63058972, 1.        ,
#         0.64644164],
#        [0.67140722, 0.77241838, 0.72151709, ..., 0.35970801, 0.64644164,
#         1.        ]])

# %%
nodes=set()
links=[]
for x in range(len(matrix)):
    for y in range(x+1, len(matrix)):
        triplet=(reverse_vocab[x],reverse_vocab[y], matrix[x][y])
        links.append(triplet)
        nodes |= set([reverse_vocab[x], reverse_vocab[y]])
                   
print('Nodes', nodes)
print('Links', links)
# Out:
# Nodes {'The Hunchback of Notre Dame', 'The Lion King', 'The Fox And The Hound', 'Piglets Big Movie', 'The Rescuers Down Under', 'Oliver and Company', 'The Little Mermaid', 'Tarzan', 'Monsters Inc', 'WALL-E', 'Hercules', 'Dinosaur', 'The Good Dinosaur', 'Brave', 'Bolt', 'Mulan', 'The AristoCats', 'Planes Fire and Rescue', 'Lilo And Stitch', 'Treasure Planet', 'A Christmas Carol', 'Frozen', 'Wreck it Ralph', 'Return to Never Land', 'Incredibles 2', 'Recess Schools Out', 'Toy Story 4', 'Snow White and the Seven Dwarfs', 'Chicken Little', 'Cinderella', 'The Princess And The Frog', 'Toy Story', 'Coco', 'Finding Nemo', 'Beauty and the Beast', 'Cars 3', 'Brother Bear', 'Ratatouille', 'DuckTales The Movie - Treasure of the Lost Lamp', 'The Incredibles', 'Zootopia', 'Up', 'Dumbo', 'One Hundred and One Dalmatians', 'Moana', 'Finding Dory', 'The Great Mouse Detective', 'Planes', 'Meet the Robinsons', 'Toy Story 3', 'A Goofy Movie', 'Winnie the Pooh', 'The Wild', 'Mars Needs Moms', 'Big Hero 6', 'Frankenweenie', 'Ralph Breaks The Internet', 'The Emperors New Groove', 'Sleeping Beauty', 'The Jungle Book', 'Arjun The Warrior Prince', 'Pocahontas', 'The Jungle Book 2', 'Alice in Wonderland', 'Toy Story 2', 'The Rescuers', 'Home on the Range', 'Aladdin', 'Atlantis-The Lost Empire', 'Bambi', "A Bug's Life", 'The Nightmare Before Christmas', 'Cars', 'The Sword in the Stone', 'Inside Out', 'Robin Hood', 'The Adventures of Ichabod and Mr Toad', 'The Black Cauldrion', 'Lady and the Tramp', 'Peter Pan', 'Tangled', 'Pinocchio', 'The Tigger Movie', 'Monsters University', 'Cars 2', 'Valiant', 'Frozen 2'}
# Links [('Snow White and the Seven Dwarfs', 'Bambi', 0.7698452472686768), ('Snow White and the Seven Dwarfs', 'Dumbo', 0.688021719455719), ('Snow White and the Seven Dwarfs', 'Pinocchio', 0.628075361251831), ('Snow White and the Seven Dwarfs', 'The Adventures of Ichabod and Mr Toad', 0.7132748365402222), ('Snow White and the Seven Dwarfs', 'Alice in Wonderland', 0.7587668895721436), ('Snow White and the Seven Dwarfs', 'Cinderella', 0.8845615386962891), ('Snow White and the Seven Dwarfs', 'Lady and the Tramp', 0.6060601472854614), ('Snow White and the Seven Dwarfs', 'Peter Pan', 0.7261248826980591), ('Snow White and the Seven Dwarfs', 'Sleeping Beauty', 0.8792978525161743), ('Snow White and the Seven Dwarfs', 'One Hundred and One Dalmatians', 0.7388707399368286), ('Snow White and the Seven Dwarfs', 'The Jungle Book', 0.5298959016799927), ('Snow White and the Seven Dwarfs', 'The Sword in the Stone', 0.770789623260498), ('Snow White and the Seven Dwarfs', 'Robin Hood', 0.7101027965545654), ('Snow White and the Seven Dwarfs', 'The AristoCats', 0.7159458994865417), ('Snow White and the Seven Dwarfs', 'The Rescuers', 0.7170979976654053), ('Snow White and the Seven Dwarfs', 'Winnie the Pooh', 0.5142537355422974), ('Snow White and the Seven Dwarfs', 'Oliver and Company', 0.3964228630065918), ('Snow White and the Seven Dwarfs', 'The Black Cauldrion', 0.8013834953308105), ('Snow White and the Seven Dwarfs', 'The Fox And The Hound', 0.5619055032730103), ('Snow White and the Seven Dwarfs', 'The Great Mouse Detective', 0.7841635942459106), ('Snow White and the Seven Dwarfs', 'The Little Mermaid', 0.7597348690032959), ('Snow White and the Seven Dwarfs', "A Bug's Life", 0.49460381269454956), ('Snow White and the Seven Dwarfs', 'A Goofy Movie', 0.3840317726135254), ('Snow White and the Seven Dwarfs', 'Aladdin', 0.780053973197937), ('Snow White and the Seven Dwarfs', 'Beauty and the Beast', 0.838577151298523), ('Snow White and the Seven Dwarfs', 'DuckTales The Movie - Treasure of the Lost Lamp', 0.7803761959075928), ('Snow White and the Seven Dwarfs', 'Hercules', 0.39253899455070496), ('Snow White and the Seven Dwarfs', 'Mulan', 0.8130650520324707), ('Snow White and the Seven Dwarfs', 'Pocahontas', 0.7560214996337891), ('Snow White and the Seven Dwarfs', 'Tarzan', 0.7416298389434814), ('Snow White and the Seven Dwarfs', 'The Hunchback of Notre Dame', 0.8744907379150391), ('Snow White and the Seven Dwarfs', 'The Lion King', 0.5852867364883423), ('Snow White and the Seven Dwarfs', 'The Nightmare Before Christmas', 0.7386475801467896), ('Snow White and the Seven Dwarfs', 'The Rescuers Down Under', 0.5560537576675415), ('Snow White and the Seven Dwarfs', 'Toy Story 2', 0.43525049090385437), ('Snow White and the Seven Dwarfs', 'Toy Story', 0.3710019886493683), ('Snow White and the Seven Dwarfs', 'A Christmas Carol', 0.7921417355537415), ('Snow White and the Seven Dwarfs', 'Atlantis-The Lost Empire', 0.7166978120803833), ('Snow White and the Seven Dwarfs', 'Bolt', 0.6024137735366821), ('Snow White and the Seven Dwarfs', 'Brother Bear', 0.7121964693069458), ('Snow White and the Seven Dwarfs', 'Cars', 0.34261196851730347), ('Snow White and the Seven Dwarfs', 'Chicken Little', 0.6788805723190308), ('Snow White and the Seven Dwarfs', 'Dinosaur', 0.6861474514007568), ('Snow White and the Seven Dwarfs', 'Finding Nemo', 0.3594137132167816), ('Snow White and the Seven Dwarfs', 'Home on the Range', 0.697335958480835), ('Snow White and the Seven Dwarfs', 'Lilo And Stitch', 0.8247307538986206), ('Snow White and the Seven Dwarfs', 'Meet the Robinsons', 0.6583549380302429), ('Snow White and the Seven Dwarfs', 'Monsters Inc', 0.49699926376342773), ('Snow White and the Seven Dwarfs', 'Piglets Big Movie', 0.654263973236084), ('Snow White and the Seven Dwarfs', 'Ratatouille', 0.6093747615814209), ('Snow White and the Seven Dwarfs', 'Recess Schools Out', 0.5122596621513367), ('Snow White and the Seven Dwarfs', 'Return to Never Land', 0.7021728754043579), ('Snow White  ...

# %%
graph = dict()
graph["nodes"] = [{"id": t, "decade": dd[t]} for t in nodes]
graph["links"] = [{"source":t[0], "target":t[1], "value":float(t[2])} for t in links]
with open('data_full.json', 'w') as outfile:
    json.dump(graph, outfile)

# %%
#aggiungendo una threshold
# nodes=set()
# links=[]
# for x in range(len(matrix)):
#     for y in range(x+1, len(matrix)):
#         if matrix[x][y] >= 0.92:
#             triplet=(reverse_vocab[x],reverse_vocab[y], matrix[x][y])
#             links.append(triplet)
#             nodes |= set([reverse_vocab[x], reverse_vocab[y]])
                   
# print('Nodes', nodes)
# print('Links', links)
